# %%
import pandas as pd
schedule = pd.read_csv("../data/2026-sp.csv")
schedule

#schedule.columns
schedule.loc[0]
# Out:
# Year                                                                 2026
# Term                                                               Spring
# YearTerm                                                          2026-sp
# Subject                                                               AAS
# Number                                                                100
# Name                                         Intro Asian American Studies
# Description             Interdisciplinary introduction to the basic co...
# Credit Hours                                                     3 hours.
# Section Info                                                          NaN
# Degree Attributes       Social & Beh Sci - Soc Sci, and Cultural Studi...
# Schedule Information                                                  NaN
# CRN                                                                 30107
# Section                                                               AD1
# Status Code                                                             A
# Part of Term                                                            1
# Section Title                                                         NaN
# Section Credit Hours                                                  NaN
# Section Status                                                          A
# Enrollment Status                                                    Open
# Type                                                Discussion/Recitation
# Type Code                                                             DIS
# Start Time                                                       09:00 AM
# End Time                                                         09:50 AM
# Days of Week                                                            F
# Room                                                                 1030
# Building                                    Literatures, Cultures, & Ling
# Instructors                                             Siglos, D;Wang, Y
# Name: 0, dtype: object

# %%
ns = {"ns2": "http://rest.cis.illinois.edu"}

# %%
allSubjects = pd.read_xml("https://courses.illinois.edu/cisapp/explorer/catalog/2026/spring.xml", xpath="/ns2:term/subjects/*", namespaces=ns)
allSubjects
# Out:
#        id                                               href  \
# 0     AAS  https://courses.illinois.edu/cisapp/explorer/c...
# 1     ABE  https://courses.illinois.edu/cisapp/explorer/c...
# 2    ACCY  https://courses.illinois.edu/cisapp/explorer/c...
# 3     ACE  https://courses.illinois.edu/cisapp/explorer/c...
# 4    ACES  https://courses.illinois.edu/cisapp/explorer/c...
# ..    ...                                                ...
# 180   VCM  https://courses.illinois.edu/cisapp/explorer/c...
# 181    VM  https://courses.illinois.edu/cisapp/explorer/c...
# 182  WGGP  https://courses.illinois.edu/cisapp/explorer/c...
# 183  WLOF  https://courses.illinois.edu/cisapp/explorer/c...
# 184  WRIT  https://courses.illinois.edu/cisapp/explorer/c...
#
#                                                subject
# 0                               Asian American Studies
# 1              Agricultural and Biological Engineering
# 2                                          Accountancy
# 3                  Agricultural and Consumer Economics
# 4    Agricultural, Consumer and Environmental Sciences
# ..                                                 ...
# 180                       Veterinary Clinical Medicine
# 181                        Veterinary Medicine Courses
# 182    Women and Gender in Global Perspectives Program
# 183                                              Wolof
# 184                                    Writing Studies
#
# [185 rows x 3 columns]

# %%
import requests
import xml.etree.ElementTree as ET
import time

rows = []
for i, subjectRow in allSubjects.iterrows():
  print(f"{i}: {subject}")
  subject = subjectRow["id"]  # ex: "CS"
  subjectName = subjectRow["subject"]  # ex: "Computer Science"
  subjectHref = subjectRow["href"]
  courses = pd.read_xml(subjectHref, xpath="/ns2:subject/courses/*", namespaces=ns)
  time.sleep(1)

  for j, courseRow in courses.iterrows():
    number = courseRow["id"]
    courseHref = courseRow["href"]
    courseName = courseRow["course"]

    row = pd.Series()
    row["Year"] = 2026
    row["Term"] = "Spring"
    row["YearTerm"] = "2026-sp"
    row["Subject"] = subject
    row["Number"] = number
    row["Name"] = courseName

    cachedRows = schedule[ (schedule.Subject == subject) & (schedule.Number == number) ]
    if len(cachedRows) == 0:
      print(f"Fetching: {subject} {number}")      
      courseXML = requests.get(courseHref).text
      time.sleep(1)

      root = ET.fromstring(courseXML)
      course_parsed = {}
      for tag in ["label", "description", "creditHours", "courseSectionInformation", "sectionDegreeAttributes", "classScheduleInformation"]:
        el = root.find(tag)
        course_parsed[tag] = el.text if el is not None else None
      row["Description"] = course_parsed["description"]
      row["Credit Hours"] = course_parsed["creditHours"]
      row["Section Info"] = course_parsed["courseSectionInformation"]
      row["Degree Attributes"] = course_parsed["sectionDegreeAttributes"]
      row["Schedule Information"] = course_parsed["classScheduleInformation"]
    else:
      print(f"Cached: {subject} {number}")
      cache = cachedRows.iloc[0]
      d = {}
      for key in ["Name", "Description", "Credit Hours", "Section Info", "Degree Attributes", "Schedule Information"]:
        row[key] = cache[key]

    rows.append(row)
# Out:
# 0: AAS
# Cached: AAS 100
# Fetching: AAS 105
# Fetching: AAS 120
# Fetching: AAS 199
# Cached: AAS 200
# Cached: AAS 201
# Fetching: AAS 203
# Fetching: AAS 211
# Cached: AAS 215
# Cached: AAS 246
# Fetching: AAS 258
# Fetching: AAS 260
# Fetching: AAS 275
# Fetching: AAS 281
# Fetching: AAS 282
# Cached: AAS 283
# Cached: AAS 286
# Cached: AAS 287
# Cached: AAS 288
# Fetching: AAS 290
# Fetching: AAS 291
# Cached: AAS 297
# Fetching: AAS 299
# Cached: AAS 300
# Cached: AAS 310
# Fetching: AAS 315
# Fetching: AAS 317
# Fetching: AAS 343
# Fetching: AAS 346
# Cached: AAS 355
# Cached: AAS 357
# Fetching: AAS 365
# Cached: AAS 370
# Fetching: AAS 375
# Cached: AAS 390
# Fetching: AAS 395
# Fetching: AAS 400
# Fetching: AAS 402
# Fetching: AAS 435
# Fetching: AAS 464
# Cached: AAS 465
# Fetching: AAS 479
# Fetching: AAS 490
# Fetching: AAS 494
# Fetching: AAS 495
# Cached: AAS 496
# Fetching: AAS 501
# Fetching: AAS 539
# Cached: AAS 561
# Fetching: AAS 589
# Fetching: AAS 590
# Fetching: AAS 594
# Fetching: AAS 596
# 1: AAS
# Fetching: ABE 127
# Cached: ABE 128
# Cached: ABE 152
# Cached: ABE 199
# Fetching: ABE 227
# Cached: ABE 228
# Fetching: ABE 232
# Fetching: ABE 340
# Cached: ABE 341
# Cached: ABE 361
# Cached: ABE 397
# Fetching: ABE 398
# Fetching: ABE 412
# Cached: ABE 425
# Fetching: ABE 426
# Fetching: ABE 430
# Fetching: ABE 436
# Fetching: ABE 445
# Fetching: ABE 446
# Cached: ABE 452
# Cached: ABE 454
# Fetching: ABE 455
# Fetching: ABE 456
# Fetching: ABE 457
# Fetching: ABE 458
# Fetching: ABE 459
# Fetching: ABE 466
# Cached: ABE 469
# Fetching: ABE 476
# Fetching: ABE 482
# Cached: ABE 483
# Fetching: ABE 488
# Cached: ABE 497
# Cached: ABE 498
# Fetching: ABE 501
# Cached: ABE 502
# Fetching: ABE 503
# Fetching: ABE 526
# Fetching: ABE 532
# Cached: ABE 597
# Fetching: ABE 598
# Fetching: ABE 599
# 2: ABE
# Cached: ACCY 199
# Cached: ACCY 200
# Cached: ACCY 201
# Cached: ACCY 202
# Cached: ACCY 290
# Cached: ACCY 301
# Cached: ACCY 302
# Cached: ACCY 303
# Cached: ACCY 304
# Cached: ACCY 312
# Cached: ACCY 321
# Cached: ACCY 375
# Cached: ACCY 398
# Cached: ACCY 405
# Cached: ACCY 410
# Fetching: ACCY 415
# Cached: ACCY 419
# Cached: ACCY 449
# Cached: ACCY 451
# Cached: ACCY 499
# Cached: ACCY 500
# Cached: ACCY 501
# Cached: ACCY 502
# Cached: ACCY 503
# Fetching: ACCY 504
# Cached: ACCY 505
# Cached: ACCY 506
# Cached: ACCY 507
# Cached: ACCY 510
# Fetching: ACCY 511
# Cached: ACCY 512
# Cached: ACCY 515
# Cached: ACCY 516
# Cached: ACCY 517
# Cached: ACCY 518
# Cached: ACCY 519
# Fetching: ACCY 531
# Fetching: ACCY 532
# Cached: ACCY 550
# Cached: ACCY 551
# Cached: ACCY 552
# Fetching: ACCY 553
# Cached: ACCY 554
# Fetching: ACCY 555
# Fetching: ACCY 556
# Fetching: ACCY 557
# Fetching: ACCY 558
# Fetching: ACCY 559
# Fetching: ACCY 561
# Fetching: ACCY 562
# Fetching: ACCY 563
# Fetching: ACCY 564
# Fetching: ACCY 569
# Cached: ACCY 570
# Cached: ACCY 571
# Cached: ACCY 574
# Cached: ACCY 575
# Cached: ACCY 576
# Cached: ACCY 577
# Cached: ACCY 578
# Fetching: ACCY 585
# Cached: ACCY 590
# Fetching: ACCY 592
# Cached: ACCY 593
# Cached: ACCY 594
# Cached: ACCY 595
# Cached: ACCY 599
# 3: ACCY
# Cached: ACE 100
# Fetching: ACE 123
# Cached: ACE 161
# Cached: ACE 199
# Fetching: ACE 203
# Cached: ACE 210
# Fetching: ACE 220
# Cached: ACE 221
# Fetching: ACE 222
# Cached: ACE 231
# Cached: ACE 232
# Cached: ACE 240
# Cached: ACE 241
# Cached: ACE 242
# Fetching: ACE 243
# Cached: ACE 251
# Fetching: ACE 254
# Fetching: ACE 255
# Cached: ACE 262
# Cached: ACE 264
# Cached: ACE 270
# Fetching: ACE 280
# Fetching: ACE 291
# Cached: ACE 292
# Cached: ACE 293
# Cached: ACE 294
# Cached: ACE 295
# Cached: ACE 300
# Cached: ACE 306
# Cached: ACE 310
# Cached: ACE 321
# Fetching: ACE 335
# Fetching: ACE 341
# Cached: ACE 344
# Cached: ACE 345
# Fetching: ACE 346
# Cached: ACE 349
# Cached: ACE 360
# Cached: ACE 396
# Cached: ACE 398
# Cached: ACE 403
# Fetching: ACE 406
# Cached: ACE 407
# Fetching: ACE 408
# Cached: ACE 410
# Fetching: ACE 411
# Fetching: ACE 417
# Cached: ACE 427
# Cached: ACE 428
# Cached: ACE 430
# Fetching: ACE 431
# Fetching: ACE 432
# Fetching: ACE 435
# Cached: ACE 436
# Cached: ACE 440
# Cached: ACE 441
# Cached: ACE 444
# Fetching: ACE 445
# Cached: ACE 446
# Cached: ACE 449
# Cached: ACE 451
# Fetching: ACE 452
# Fetching: ACE 455
# Cached: ACE 456
# Cached: ACE 474
# Cached: ACE 476
# Fetching: ACE 478
# Cached: ACE 499
# Fetching: ACE 500
# Fetching: ACE 501
# Fetching: ACE 502
# Cached: ACE 503
# Fetching: ACE 504
# Cached: ACE 505
# Cached: ACE 510
# Fetching: ACE 516
# Fetching: ACE 520
# Fetching: ACE 527
# Fetching: ACE 528
# Cached: ACE 530
# Cached: ACE 531
# Fetching: ACE 532
# Fetching: ACE 542
# Fetching: ACE 544
# Fetching: ACE 545
# Fetching: ACE 546
# Fetching: ACE 547
# Fetching: ACE 557
# Fetching: ACE 559
# Cached: ACE 561
# Fetching: ACE 562
# Cached: ACE 563
# Fetching: ACE 564
# Fetching: ACE 569
# Cached: ACE 571
# Fetching: ACE 580
# Fetching: ACE 581
# Fetching: ACE 582
# Cached: ACE 591
# Cached: ACE 592
# Cached: ACE 594
# Fetching: ACE 599
# 4: ACE
# Fetching: ACES 101
# Cached: ACES 102
# Fetching: ACES 123
# Fetching: ACES 179
# Fetching: ACES 199
# Cached: ACES 200
# Cached: ACES 293
# Fetching: ACES 295
# Cached: ACES 298
# Cached: ACES 299
# Fetching: ACES 360
# Fetching: ACES 396
# Fetching: ACES 398
# Fetching: ACES 399
# Fetching: ACES 499
# 5: ACES
# Cached: ADV 120
# Cached: ADV 150
# Cached: ADV 175
# Fetching: ADV 199
# Cached: ADV 200
# Cached: ADV 201
# Fetching: ADV 212
# Cached: ADV 214
# Cached: ADV 222
# Cached: ADV 250
# Cached: ADV 270
# Cached: ADV 280
# Cached: ADV 281
# Cached: ADV 284
# Cached: ADV 290
# Cached: ADV 301
# Fetching: ADV 305
# Cached: ADV 310
# Fetching: ADV 311
# Cached: ADV 314
# Cached: ADV 320
# Cached: ADV 333
# Cached: ADV 350
# Cached: ADV 360
# Cached: ADV 370
# Fetching: ADV 376
# Fetching: ADV 378
# Cached: ADV 390
# Cached: ADV 391
# Cached: ADV 392
# Cached: ADV 393
# Cached: ADV 396
# Fetching: ADV 399
# Cached: ADV 400
# Cached: ADV 409
# Cached: ADV 410
# Fetching: ADV 452
# Cached: ADV 454
# Cached: ADV 461
# Fetching: ADV 462
# Fetching: ADV 475
# Cached: ADV 480
# Fetching: ADV 482
# Cached: ADV 483
# Fetching: ADV 484
# Cached: ADV 490
# Cached: ADV 491
# Cached: ADV 492
# Fetching: ADV 494
# Cached: ADV 495
# Cached: ADV 496
# Cached: ADV 497
# Cached: ADV 498
# Cached: ADV 509
# Fetching: ADV 550
# Fetching: ADV 580
# Fetching: ADV 581
# Cached: ADV 582
# Fetching: ADV 587
# Cached: ADV 588
# Cached: ADV 590
# Fetching: ADV 594
# Cached: ADV 597
# Cached: ADV 598
# Fetching: ADV 599
# 6: ADV
# Fetching: AE 100
# Cached: AE 140
# Cached: AE 199
# Cached: AE 202
# Cached: AE 298
# Fetching: AE 302
# Cached: AE 311
# Cached: AE 312
# Cached: AE 321
# Cached: AE 323
# Cached: AE 352
# Cached: AE 353
# Cached: AE 370
# Cached: AE 395
# Cached: AE 396
# Cached: AE 397
# Cached: AE 398
# Fetching: AE 402
# Cached: AE 403
# Cached: AE 410
# Fetching: AE 412
# Fetching: AE 416
# Cached: AE 419
# Cached: AE 420
# Fetching: AE 428
# Fetching: AE 433
# Cached: AE 434
# Cached: AE 435
# Cached: AE 442
# Cached: AE 443
# Fetching: AE 445
# Fetching: AE 451
# Fetching: AE 452
# Fetching: AE 454
# Fetching: AE 456
# Fetching: AE 460
# Cached: AE 461
# Cached: AE 462
# Fetching: AE 468
# Fetching: AE 480
# Cached: AE 482
# Fetching: AE 483
# Cached: AE 484
# Fetching: AE 485
# Cached: AE 497
# Cached: AE 498
# Cached: AE 502
# Fetching: AE 504
# Fetching: AE 508
# Cached: AE 510
# Fetching: AE 511
# Fetching: AE 512
# Fetching: AE 514
# Cached: AE 515
# Fetching: AE 521
# Cached: AE 522
# Fetching: AE 523
# Fetching: AE 524
# Fetching: AE 525
# Cached: AE 526
# Fetching: AE 527
# Fetching: AE 528
# Fetching: AE 529
# Cached: AE 538
# Fetching: AE 542
# Cached: AE 543
# Fetching: AE 550
# Fetching: AE 551
# Cached: AE 554
# Fetching: AE 555
# Fetching: AE 556
# Fetching: AE 560
# Fetching: AE 564
# Cached: AE 590
# Cached: AE 597
# Cached: AE 598
# Fetching: AE 599
# 7: AE
# Fetching: AFAS 100
# Cached: AFAS 102
# Cached: AFAS 112
# Fetching: AFAS 120
# Fetching: AFAS 221
# Cached: AFAS 222
# Fetching: AFAS 331
# Cached: AFAS 332
# Fetching: AFAS 341
# Cached: AFAS 342
# 8: AFAS
# Fetching: AFRO 100
# Fetching: AFRO 101
# Fetching: AFRO 103
# Fetching: AFRO 105
# Cached: AFRO 106
# Cached: AFRO 122
# Cached: AFRO 132
# Fetching: AFRO 134
# Fetching: AFRO 199
# Cached: AFRO 201
# Fetching: AFRO 211
# Fetching: AFRO 212
# Cached: AFRO 215
# Fetching: AFRO 220
# Cached: AFRO 221
# Cached: AFRO 224
# Cached: AFRO 226
# Fetching: AFRO 227
# Cached: AFRO 228
# Fetching: AFRO 231
# Fetching: AFRO 234
# Cached: AFRO 243
# Cached: AFRO 250
# Fetching: AFRO 259
# Cached: AFRO 260
# Cached: AFRO 261
# Fetching: AFRO 275
# Cached: AFRO 276
# Fetching: AFRO 281
# Fetching: AFRO 287
# Fetching: AFRO 290
# Cached: AFRO 298
# Cached: AFRO 310
# Fetching: AFRO 312
# Fetching: AFRO 315
# Cached: AFRO 340
# Fetching: AFRO 341
# Cached: AFRO 342
# Fetching: AFRO 343
# Fetching: AFRO 345
# Fetching: AFRO 372
# Fetching: AFRO 373
# Cached: AFRO 378
# Fetching: AFRO 380
# Cached: AFRO 381
# Fetching: AFRO 382
# Fetching: AFRO 383
# Fetching: AFRO 398
# Fetching: AFRO 400
# Fetching: AFRO 407
# Fetching: AFRO 410
# Fetching: AFRO 411
# Cached: AFRO 415
# Cached: AFRO 421
# Fetching: AFRO 435
# Fetching: AFRO 460
# Cached: AFRO 465
# Fetching: AFRO 466
# Fetching: AFRO 474
# Fetching: AFRO 481
# Fetching: AFRO 482
# Fetching: AFRO 490
# Cached: AFRO 495
# Cached: AFRO 498
# Fetching: AFRO 500
# Cached: AFRO 501
# Fetching: AFRO 502
# Fetching: AFRO 504
# Cached: AFRO 531
# Fetching: AFRO 552
# Fetching: AFRO 560
# Fetching: AFRO 595
# Cached: AFRO 597
# Cached: AFRO 598
# Fetching: AFRO 599
# 9: AFRO
# Fetching: AFST 103
# Fetching: AFST 111
# Cached: AFST 112
# Cached: AFST 199
# Cached: AFST 209
# Cached: AFST 210
# Cached: AFST 213
# Cached: AFST 222
# Fetching: AFST 231
# Cached: AFST 232
# Fetching: AFST 233
# Cached: AFST 241
# Cached: AFST 242
# Cached: AFST 243
# Fetching: AFST 254
# Fetching: AFST 312
# Fetching: AFST 313
# Fetching: AFST 338
# Fetching: AFST 405
# Fetching: AFST 406
# Fetching: AFST 407
# Fetching: AFST 408
# Fetching: AFST 410
# Fetching: AFST 412
# Cached: AFST 420
# Fetching: AFST 421
# Fetching: AFST 433
# Cached: AFST 434
# Fetching: AFST 435
# Cached: AFST 436
# Cached: AFST 443
# Fetching: AFST 444
# Fetching: AFST 445
# Fetching: AFST 446
# Fetching: AFST 447
# Cached: AFST 490
# Fetching: AFST 495
# Fetching: AFST 509
# Fetching: AFST 510
# Fetching: AFST 511
# Cached: AFST 515
# Fetching: AFST 522
# Cached: AFST 550
# Fetching: AFST 555
# Fetching: AFST 560
# Fetching: AFST 599
# 10: AFST
# Fetching: AGCM 199
# Cached: AGCM 220
# Cached: AGCM 310
# Fetching: AGCM 315
# Fetching: AGCM 330
# Fetching: AGCM 375
# Fetching: AGCM 380
# Cached: AGCM 398
# Fetching: AGCM 420
# Cached: AGCM 440
# Cached: AGCM 495
# Fetching: AGCM 499
# 11: AGCM
# Cached: AGED 199
# Fetching: AGED 220
# Cached: AGED 250
# Fetching: AGED 293
# Fetching: AGED 295
# Fetching: AGED 350
# Fetching: AGED 396
# Cached: AGED 410
# Cached: AGED 420
# Fetching: AGED 421
# Fetching: AGED 430
# Cached: AGED 450
# Fetching: AGED 496
# Fetching: AGED 498
# Fetching: AGED 499
# Fetching: AGED 500
# Fetching: AGED 501
# Fetching: AGED 510
# Fetching: AGED 511
# Fetching: AGED 550
# Fetching: AGED 551
# 12: AGED
# Fetching: AHS 125
# Cached: AHS 199
# Cached: AHS 292
# Fetching: AHS 294
# Fetching: AHS 399
# Fetching: AHS 494
# 13: AHS
# Cached: AIS 101
# Fetching: AIS 140
# Fetching: AIS 165
# Fetching: AIS 199
# Fetching: AIS 214
# Cached: AIS 265
# Fetching: AIS 275
# Fetching: AIS 277
# Cached: AIS 278
# Fetching: AIS 280
# Cached: AIS 285
# Fetching: AIS 288
# Fetching: AIS 291
# Cached: AIS 295
# Fetching: AIS 343
# Cached: AIS 357
# Fetching: AIS 459
# Cached: AIS 481
# Fetching: AIS 490
# Cached: AIS 491
# Cached: AIS 501
# Fetching: AIS 502
# Cached: AIS 503
# Fetching: AIS 590
# Fetching: AIS 591
# 14: AIS
# Fetching: ALEC 110
# Cached: ALEC 115
# Fetching: ALEC 123
# Fetching: ALEC 293
# Fetching: ALEC 294
# Fetching: ALEC 295
# Cached: ALEC 393
# Fetching: ALEC 396
# Fetching: ALEC 398
# Fetching: ALEC 451
# Fetching: ALEC 490
# Fetching: ALEC 491
# Fetching: ALEC 492
# Fetching: ALEC 494
# Fetching: ALEC 499
# Fetching: ALEC 500
# Cached: ALEC 505
# Fetching: ALEC 510
# Cached: ALEC 540
# Fetching: ALEC 545
# Fetching: ALEC 549
# Fetching: ALEC 595
# Fetching: ALEC 599
# 15: ALEC
# Cached: ANSC 100
# Fetching: ANSC 101
# Cached: ANSC 103
# Fetching: ANSC 110
# Cached: ANSC 120
# Fetching: ANSC 198
# Cached: ANSC 199
# Cached: ANSC 201
# Cached: ANSC 205
# Fetching: ANSC 206
# Cached: ANSC 207
# Cached: ANSC 210
# Cached: ANSC 211
# Cached: ANSC 215
# Fetching: ANSC 221
# Fetching: ANSC 222
# Cached: ANSC 223
# Cached: ANSC 224
# Cached: ANSC 250
# Fetching: ANSC 251
# Cached: ANSC 255
# Fetching: ANSC 256
# Cached: ANSC 298
# Cached: ANSC 301
# Fetching: ANSC 305
# Cached: ANSC 306
# Fetching: ANSC 307
# Fetching: ANSC 309
# Fetching: ANSC 310
# Fetching: ANSC 312
# Fetching: ANSC 313
# Fetching: ANSC 314
# Fetching: ANSC 322
# Fetching: ANSC 350
# Cached: ANSC 363
# Cached: ANSC 366
# Fetching: ANSC 370
# Cached: ANSC 398
# Fetching: ANSC 399
# Fetching: ANSC 400
# Fetching: ANSC 401
# Cached: ANSC 402
# Fetching: ANSC 403
# Cached: ANSC 404
# Fetching: ANSC 406
# Cached: ANSC 407
# Cached: ANSC 409
# Fetching: ANSC 420
# Fetching: ANSC 421
# Fetching: ANSC 422
# Fetching: ANSC 424
# Fetching: ANSC 431
# Fetching: ANSC 435
# Cached: ANSC 438
# Cached: ANSC 440
# Fetching: ANSC 441
# Cached: ANSC 442
# Fetching: ANSC 444
# Fetching: ANSC 445
# Cached: ANSC 446
# Fetching: ANSC 449
# Cached: ANSC 450
# Fetching: ANSC 451
# Fetching: ANSC 452
# Fetching: ANSC 454
# Cached: ANSC 464
# Fetching: ANSC 467
# Cached: ANSC 470
# Fetching: ANSC 471
# Cached: ANSC 480
# Cached: ANSC 498
# Cached: ANSC 499
# Cached: ANSC 500
# Cached: ANSC 501
# Fetching: ANSC 502
# Cached: ANSC 520
# Cached: ANSC 521
# Fetching: ANSC 522
# Fetching: ANSC 523
# Fetching: ANSC 524
# Cached: ANSC 525
# Cached: ANSC 526
# Fetching: ANSC 533
# Fetching: ANSC 541
# Cached: ANSC 542
# Cached: ANSC 543
# Cached: ANSC 580
# Cached: ANSC 590
# Cached: ANSC 591
# Fetching: ANSC 592
# Cached: ANSC 593
# Fetching: ANSC 599
# 16: ANSC
# Cached: ANTH 101
# Fetching: ANTH 102
# Cached: ANTH 103
# Fetching: ANTH 104
# Fetching: ANTH 105
# Cached: ANTH 106
# Fetching: ANTH 108
# Cached: ANTH 109
# Cached: ANTH 110
# Cached: ANTH 112
# Cached: ANTH 126
# Fetching: ANTH 130
# Fetching: ANTH 143
# Fetching: ANTH 157
# Fetching: ANTH 160
# Fetching: ANTH 165
# Fetching: ANTH 175
# Cached: ANTH 180
# Cached: ANTH 182
# Cached: ANTH 199
# Fetching: ANTH 209
# Cached: ANTH 210
# Fetching: ANTH 220
# Cached: ANTH 221
# Cached: ANTH 222
# Cached: ANTH 230
# Cached: ANTH 240
# Fetching: ANTH 241
# Fetching: ANTH 242
# Cached: ANTH 243
# Cached: ANTH 246
# Cached: ANTH 247
# Fetching: ANTH 248
# Fetching: ANTH 249
# Cached: ANTH 250
# Fetching: ANTH 258
# Fetching: ANTH 259
# Cached: ANTH 261
# Fetching: ANTH 262
# Fetching: ANTH 263
# Fetching: ANTH 268
# Cached: ANTH 270
# Fetching: ANTH 272
# Cached: ANTH 278
# Fetching: ANTH 279
# Fetching: ANTH 280
# Fetching: ANTH 285
# Cached: ANTH 287
# Fetching: ANTH 288
# Fetching: ANTH 290
# Fetching: ANTH 310
# Fetching: ANTH 315
# Fetching: ANTH 339
# Fetching: ANTH 340
# Cached: ANTH 342
# Fetching: ANTH 343
# Fetching: ANTH 346
# Cached: ANTH 347
# Cached: ANTH 350
# Fetching: ANTH 351
# Cached: ANTH 352
# Fetching: ANTH 353
# Fetching: ANTH 358
# Fetching: ANTH 360
# Cached: ANTH 361
# Fetching: ANTH 363
# Fetching: ANTH 364
# Cached: ANTH 368
# Fetching: ANTH 370
# Cached: ANTH 372
# Fetching: ANTH 374
# Fetching: ANTH 375
# Cached: ANTH 379
# Cached: ANTH 387
# Cached: ANTH 390
# Fetching: ANTH 399
# Fetching: ANTH 403
# Fetching: ANTH 404
# Fetching: ANTH 405
# Fetching: ANTH 407
# Fetching: ANTH 408
# Cached: ANTH 411
# Fetching: ANTH 414
# Fetching: ANTH 416
# Cached: ANTH 420
# Fetching: ANTH 421
# Fetching: ANTH 423
# Fetching: ANTH 426
# Fetching: ANTH 430
# Cached: ANTH 432
# Fetching: ANTH 433
# Fetching: ANTH 435
# Cached: ANTH 436
# Fetching: ANTH 437
# Fetching: ANTH 438
# Fetching: ANTH 440
# Fetching: ANTH 441
# Fetching: ANTH 443
# Cached: ANTH 444
# Cached: ANTH 445
# Cached: ANTH 447
# Cached: ANTH 448
# Fetching: ANTH 449
# Cached: ANTH 450
# Cached: ANTH 451
# Fetching: ANTH 452
# Fetching: ANTH 453
# Cached: ANTH 454
# Cached: ANTH 455
# Fetching: ANTH 456
# Fetching: ANTH 459
# Fetching: ANTH 460
# Cached: ANTH 461
# Cached: ANTH 462
# Fetching: ANTH 463
# Fetching: ANTH 464
# Fetching: ANTH 466
# Cached: ANTH 467
# Cached: ANTH 468
# Fetching: ANTH 470
# Fetching: ANTH 471
# Fetching: ANTH 472
# Fetching: ANTH 477
# Fetching: ANTH 479
# Fetching: ANTH 481
# Fetching: ANTH 485
# Fetching: ANTH 488
# Fetching: ANTH 494
# Cached: ANTH 495
# Cached: ANTH 496
# Cached: ANTH 497
# Fetching: ANTH 498
# Cached: ANTH 499
# Fetching: ANTH 503
# Cached: ANTH 504
# Cached: ANTH 511
# Fetching: ANTH 512
# Fetching: ANTH 514
# Cached: ANTH 515
# Fetching: ANTH 518
# Fetching: ANTH 523
# Fetching: ANTH 532
# Fetching: ANTH 540
# Fetching: ANTH 552
# Fetching: ANTH 555
# Fetching: ANTH 557
# Fetching: ANTH 558
# Fetching: ANTH 560
# Fetching: ANTH 561
# Cached: ANTH 565
# Fetching: ANTH 570
# Cached: ANTH 589
# Cached: ANTH 590
# Fetching: ANTH 594
# Fetching: ANTH 599
# 17: ANTH
# Cached: ARAB 150
# Fetching: ARAB 199
# Fetching: ARAB 201
# Cached: ARAB 202
# Cached: ARAB 210
# Fetching: ARAB 211
# Fetching: ARAB 403
# Cached: ARAB 404
# Fetching: ARAB 405
# Cached: ARAB 406
# Fetching: ARAB 407
# Cached: ARAB 408
# Fetching: ARAB 409
# Fetching: ARAB 410
# Fetching: ARAB 412
# Fetching: ARAB 413
# Fetching: ARAB 490
# 18: ARAB
# Fetching: ARCH 101
# Fetching: ARCH 171
# Cached: ARCH 172
# Cached: ARCH 199
# Fetching: ARCH 200
# Fetching: ARCH 210
# Fetching: ARCH 211
# Cached: ARCH 222
# Fetching: ARCH 231
# Cached: ARCH 232
# Fetching: ARCH 237
# Fetching: ARCH 273
# Cached: ARCH 274
# Cached: ARCH 314
# Fetching: ARCH 315
# Fetching: ARCH 321
# Fetching: ARCH 371
# Cached: ARCH 372
# Cached: ARCH 401
# Fetching: ARCH 402
# Cached: ARCH 403
# Fetching: ARCH 407
# Cached: ARCH 409
# Fetching: ARCH 410
# Fetching: ARCH 411
# Fetching: ARCH 412
# Fetching: ARCH 414
# Cached: ARCH 415
# Cached: ARCH 416
# Fetching: ARCH 417
# Fetching: ARCH 418
# Fetching: ARCH 419
# Fetching: ARCH 424
# Fetching: ARCH 433
# Fetching: ARCH 434
# Cached: ARCH 435
# Cached: ARCH 468
# Fetching: ARCH 471
# Cached: ARCH 472
# Fetching: ARCH 473
# Cached: ARCH 474
# Fetching: ARCH 481
# Fetching: ARCH 482
# Fetching: ARCH 483
# Fetching: ARCH 484
# Fetching: ARCH 485
# Cached: ARCH 490
# Cached: ARCH 491
# Fetching: ARCH 498
# Cached: ARCH 499
# Cached: ARCH 501
# Cached: ARCH 510
# Fetching: ARCH 511
# Fetching: ARCH 512
# Fetching: ARCH 513
# Fetching: ARCH 515
# Fetching: ARCH 516
# Cached: ARCH 517
# Fetching: ARCH 518
# Fetching: ARCH 519
# Fetching: ARCH 521
# Fetching: ARCH 522
# Fetching: ARCH 523
# Fetching: ARCH 525
# Fetching: ARCH 534
# Cached: ARCH 535
# Fetching: ARCH 536
# Cached: ARCH 537
# Cached: ARCH 538
# Fetching: ARCH 550
# Fetching: ARCH 551
# Fetching: ARCH 552
# Cached: ARCH 553
# Cached: ARCH 554
# Fetching: ARCH 555
# Fetching: ARCH 556
# Fetching: ARCH 557
# Fetching: ARCH 558
# Cached: ARCH 560
# Fetching: ARCH 563
# Cached: ARCH 571
# Cached: ARCH 572
# Cached: ARCH 573
# Cached: ARCH 574
# Cached: ARCH 575
# Cached: ARCH 576
# Fetching: ARCH 577
# Cached: ARCH 588
# Fetching: ARCH 589
# Cached: ARCH 590
# Cached: ARCH 591
# Cached: ARCH 592
# Cached: ARCH 593
# Cached: ARCH 594
# Fetching: ARCH 595
# Cached: ARCH 596
# Fetching: ARCH 597
# Fetching: ARCH 598
# Fetching: ARCH 599
# 19: ARCH
# Fetching: ART 100
# Fetching: ART 102
# Cached: ART 103
# Fetching: ART 104
# Cached: ART 140
# Cached: ART 150
# Fetching: ART 151
# Fetching: ART 152
# Fetching: ART 153
# Fetching: ART 154
# Fetching: ART 155
# Cached: ART 156
# Fetching: ART 160
# Cached: ART 191
# Cached: ART 199
# Fetching: ART 201
# Fetching: ART 205
# Fetching: ART 208
# Fetching: ART 210
# Cached: ART 221
# Cached: ART 299
# Fetching: ART 310
# Fetching: ART 350
# Fetching: ART 499
# Fetching: ART 550
# Fetching: ART 553
# Fetching: ART 594
# 20: ART
# Cached: ARTD 101
# Cached: ARTD 151
# Fetching: ARTD 201
# Fetching: ARTD 202
# Fetching: ARTD 216
# Cached: ARTD 217
# Cached: ARTD 218
# Fetching: ARTD 222
# Fetching: ARTD 225
# Fetching: ARTD 228
# Fetching: ARTD 230
# Fetching: ARTD 240
# Fetching: ARTD 251
# Fetching: ARTD 270
# Fetching: ARTD 299
# Fetching: ARTD 301
# Cached: ARTD 302
# Cached: ARTD 317
# Fetching: ARTD 318
# Cached: ARTD 326
# Cached: ARTD 328
# Cached: ARTD 333
# Fetching: ARTD 351
# Fetching: ARTD 371
# Cached: ARTD 391
# Cached: ARTD 399
# Fetching: ARTD 401
# Cached: ARTD 402
# Cached: ARTD 418
# Cached: ARTD 420
# Cached: ARTD 426
# Cached: ARTD 444
# Fetching: ARTD 445
# Fetching: ARTD 448
# Fetching: ARTD 451
# Fetching: ARTD 452
# Cached: ARTD 471
# Cached: ARTD 499
# Fetching: ARTD 501
# Fetching: ARTD 502
# Cached: ARTD 503
# Fetching: ARTD 504
# Fetching: ARTD 505
# Fetching: ARTD 506
# Fetching: ARTD 510
# Fetching: ARTD 511
# Cached: ARTD 551
# Fetching: ARTD 570
# Cached: ARTD 591
# Cached: ARTD 595
# Fetching: ARTD 599
# 21: ARTD
# Cached: ARTE 101
# Fetching: ARTE 201
# Fetching: ARTE 202
# Cached: ARTE 260
# Cached: ARTE 299
# Cached: ARTE 301
# Fetching: ARTE 303
# Fetching: ARTE 304
# Fetching: ARTE 355
# Cached: ARTE 391
# Cached: ARTE 393
# Fetching: ARTE 400
# Cached: ARTE 401
# Fetching: ARTE 475
# Cached: ARTE 480
# Fetching: ARTE 501
# Fetching: ARTE 502
# Cached: ARTE 505
# Fetching: ARTE 506
# Cached: ARTE 591
# Cached: ARTE 593
# Fetching: ARTE 599
# 22: ARTE
# Fetching: ARTF 101
# Cached: ARTF 102
# Fetching: ARTF 103
# Cached: ARTF 104
# Cached: ARTF 105
# Cached: ARTF 106
# Cached: ARTF 199
# Fetching: ARTF 201
# Fetching: ARTF 301
# 23: ARTF
# Cached: ARTH 110
# Fetching: ARTH 111
# Fetching: ARTH 112
# Cached: ARTH 211
# Fetching: ARTH 212
# Fetching: ARTH 214
# Fetching: ARTH 215
# Fetching: ARTH 218
# Cached: ARTH 219
# Cached: ARTH 220
# Fetching: ARTH 222
# Cached: ARTH 230
# Fetching: ARTH 231
# Fetching: ARTH 235
# Fetching: ARTH 240
# Fetching: ARTH 241
# Fetching: ARTH 242
# Cached: ARTH 250
# Fetching: ARTH 257
# Cached: ARTH 260
# Fetching: ARTH 299
# Fetching: ARTH 300
# Fetching: ARTH 310
# Fetching: ARTH 312
# Fetching: ARTH 313
# Fetching: ARTH 320
# Fetching: ARTH 342
# Cached: ARTH 343
# Fetching: ARTH 344
# Fetching: ARTH 345
# Fetching: ARTH 350
# Fetching: ARTH 351
# Fetching: ARTH 360
# Fetching: ARTH 361
# Cached: ARTH 391
# Fetching: ARTH 402
# Fetching: ARTH 403
# Fetching: ARTH 404
# Fetching: ARTH 407
# Fetching: ARTH 410
# Fetching: ARTH 412
# Fetching: ARTH 413
# Cached: ARTH 415
# Fetching: ARTH 416
# Fetching: ARTH 423
# Fetching: ARTH 424
# Fetching: ARTH 430
# Fetching: ARTH 431
# Fetching: ARTH 432
# Fetching: ARTH 433
# Fetching: ARTH 435
# Fetching: ARTH 436
# Cached: ARTH 438
# Fetching: ARTH 440
# Fetching: ARTH 443
# Fetching: ARTH 445
# Cached: ARTH 447
# Fetching: ARTH 450
# Fetching: ARTH 460
# Cached: ARTH 462
# Cached: ARTH 489
# Cached: ARTH 490
# Cached: ARTH 491
# Cached: ARTH 495
# Fetching: ARTH 500
# Fetching: ARTH 501
# Fetching: ARTH 510
# Fetching: ARTH 515
# Fetching: ARTH 520
# Fetching: ARTH 522
# Fetching: ARTH 530
# Fetching: ARTH 531
# Cached: ARTH 535
# Fetching: ARTH 539
# Fetching: ARTH 540
# Cached: ARTH 541
# Fetching: ARTH 545
# Fetching: ARTH 546
# Fetching: ARTH 550
# Fetching: ARTH 560
# Cached: ARTH 591
# Fetching: ARTH 593
# Fetching: ARTH 599
# 24: ARTH
# Cached: ARTJ 101
# Cached: ARTJ 199
# Cached: ARTJ 209
# Fetching: ARTJ 299
# Cached: ARTJ 301
# Cached: ARTJ 302
# Cached: ARTJ 391
# Cached: ARTJ 397
# Fetching: ARTJ 398
# Cached: ARTJ 399
# Fetching: ARTJ 591
# 25: ARTJ
# Fetching: ARTS 200
# Fetching: ARTS 201
# Cached: ARTS 205
# Cached: ARTS 210
# Cached: ARTS 220
# Cached: ARTS 221
# Fetching: ARTS 223
# Fetching: ARTS 230
# Cached: ARTS 241
# Cached: ARTS 243
# Cached: ARTS 244
# Fetching: ARTS 245
# Cached: ARTS 250
# Cached: ARTS 251
# Fetching: ARTS 252
# Cached: ARTS 264
# Cached: ARTS 265
# Fetching: ARTS 266
# Fetching: ARTS 267
# Cached: ARTS 280
# Cached: ARTS 299
# Fetching: ARTS 310
# Cached: ARTS 320
# Fetching: ARTS 321
# Fetching: ARTS 340
# Fetching: ARTS 350
# Cached: ARTS 351
# Fetching: ARTS 352
# Cached: ARTS 354
# Cached: ARTS 355
# Fetching: ARTS 364
# Fetching: ARTS 365
# Cached: ARTS 367
# Cached: ARTS 381
# Cached: ARTS 391
# Cached: ARTS 392
# Fetching: ARTS 394
# Fetching: ARTS 399
# Fetching: ARTS 400
# Cached: ARTS 405
# Fetching: ARTS 410
# Cached: ARTS 420
# Fetching: ARTS 443
# Cached: ARTS 444
# Fetching: ARTS 445
# Fetching: ARTS 446
# Fetching: ARTS 448
# Fetching: ARTS 449
# Fetching: ARTS 450
# Cached: ARTS 451
# Fetching: ARTS 454
# Fetching: ARTS 455
# Fetching: ARTS 456
# Fetching: ARTS 457
# Cached: ARTS 461
# Cached: ARTS 465
# Cached: ARTS 499
# Cached: ARTS 591
# Cached: ARTS 593
# Cached: ARTS 594
# Cached: ARTS 595
# 26: ARTS
# Fetching: ASRM 101
# Fetching: ASRM 195
# Fetching: ASRM 199
# Cached: ASRM 210
# Fetching: ASRM 390
# Fetching: ASRM 392
# Cached: ASRM 398
# Cached: ASRM 401
# Fetching: ASRM 402
# Cached: ASRM 406
# Cached: ASRM 409
# Cached: ASRM 410
# Cached: ASRM 441
# Cached: ASRM 442
# Cached: ASRM 450
# Cached: ASRM 451
# Cached: ASRM 453
# Cached: ASRM 454
# Cached: ASRM 455
# Cached: ASRM 461
# Fetching: ASRM 462
# Cached: ASRM 469
# Cached: ASRM 471
# Cached: ASRM 472
# Fetching: ASRM 490
# Cached: ASRM 499
# Cached: ASRM 510
# Fetching: ASRM 533
# Cached: ASRM 539
# Cached: ASRM 551
# Cached: ASRM 555
# Fetching: ASRM 561
# Fetching: ASRM 563
# Fetching: ASRM 569
# Cached: ASRM 575
# Cached: ASRM 593
# Cached: ASRM 595
# Fetching: ASRM 597
# Cached: ASRM 598
# Fetching: ASRM 599
# 27: ASRM
# Fetching: ASST 104
# Cached: ASST 199
# Cached: ASST 208
# Fetching: ASST 346
# Fetching: ASST 347
# Cached: ASST 390
# Fetching: ASST 391
# 28: ASST
# Cached: ASTR 100
# Cached: ASTR 121
# Cached: ASTR 122
# Fetching: ASTR 150
# Fetching: ASTR 199
# Cached: ASTR 210
# Cached: ASTR 310
# Cached: ASTR 330
# Cached: ASTR 350
# Cached: ASTR 390
# Cached: ASTR 401
# Fetching: ASTR 404
# Cached: ASTR 405
# Cached: ASTR 406
# Cached: ASTR 414
# Fetching: ASTR 457
# Cached: ASTR 490
# Cached: ASTR 496
# Fetching: ASTR 499
# Fetching: ASTR 501
# Fetching: ASTR 502
# Fetching: ASTR 503
# Fetching: ASTR 504
# Fetching: ASTR 505
# Fetching: ASTR 506
# Cached: ASTR 507
# Fetching: ASTR 510
# Fetching: ASTR 515
# Cached: ASTR 516
# Fetching: ASTR 540
# Fetching: ASTR 541
# Fetching: ASTR 555
# Cached: ASTR 590
# Cached: ASTR 593
# Cached: ASTR 596
# Fetching: ASTR 599
# 29: ASTR
# Cached: ATMS 100
# Cached: ATMS 120
# Cached: ATMS 140
# Fetching: ATMS 180
# Cached: ATMS 199
# Cached: ATMS 201
# Cached: ATMS 202
# Cached: ATMS 207
# Cached: ATMS 301
# Fetching: ATMS 302
# Fetching: ATMS 303
# Cached: ATMS 304
# Fetching: ATMS 305
# Cached: ATMS 306
# Cached: ATMS 307
# Fetching: ATMS 312
# Cached: ATMS 313
# Cached: ATMS 314
# Fetching: ATMS 315
# Cached: ATMS 322
# Fetching: ATMS 323
# Fetching: ATMS 324
# Fetching: ATMS 371
# Fetching: ATMS 380
# Cached: ATMS 390
# Fetching: ATMS 391
# Cached: ATMS 402
# Fetching: ATMS 404
# Fetching: ATMS 405
# Fetching: ATMS 406
# Fetching: ATMS 407
# Fetching: ATMS 410
# Fetching: ATMS 411
# Fetching: ATMS 413
# Fetching: ATMS 417
# Fetching: ATMS 420
# Fetching: ATMS 421
# Fetching: ATMS 423
# Fetching: ATMS 424
# Fetching: ATMS 446
# Fetching: ATMS 447
# Fetching: ATMS 449
# Cached: ATMS 450
# Fetching: ATMS 490
# Fetching: ATMS 491
# Cached: ATMS 492
# Fetching: ATMS 500
# Cached: ATMS 502
# Cached: ATMS 505
# Cached: ATMS 507
# Fetching: ATMS 510
# Fetching: ATMS 511
# Fetching: ATMS 512
# Fetching: ATMS 514
# Cached: ATMS 517
# Fetching: ATMS 520
# Fetching: ATMS 521
# Fetching: ATMS 523
# Cached: ATMS 526
# Fetching: ATMS 535
# Fetching: ATMS 540
# Fetching: ATMS 571
# Fetching: ATMS 590
# Cached: ATMS 591
# Cached: ATMS 596
# Fetching: ATMS 597
# Cached: ATMS 599
# 30: ATMS
# Cached: BADM 199
# Cached: BADM 205
# Cached: BADM 210
# Cached: BADM 211
# Cached: BADM 261
# Cached: BADM 275
# Cached: BADM 300
# Cached: BADM 303
# Cached: BADM 310
# Cached: BADM 311
# Cached: BADM 312
# Cached: BADM 313
# Cached: BADM 314
# Cached: BADM 320
# Fetching: BADM 321
# Cached: BADM 322
# Cached: BADM 323
# Cached: BADM 324
# Cached: BADM 325
# Cached: BADM 326
# Fetching: BADM 327
# Fetching: BADM 328
# Cached: BADM 329
# Cached: BADM 330
# Cached: BADM 331
# Fetching: BADM 332
# Fetching: BADM 333
# Fetching: BADM 334
# Cached: BADM 335
# Cached: BADM 336
# Cached: BADM 337
# Fetching: BADM 338
# Cached: BADM 340
# Cached: BADM 341
# Cached: BADM 346
# Cached: BADM 350
# Cached: BADM 351
# Cached: BADM 352
# Cached: BADM 353
# Cached: BADM 356
# Fetching: BADM 357
# Cached: BADM 358
# Cached: BADM 359
# Fetching: BADM 360
# Fetching: BADM 361
# Cached: BADM 362
# Cached: BADM 364
# Fetching: BADM 365
# Cached: BADM 366
# Fetching: BADM 367
# Cached: BADM 370
# Cached: BADM 371
# Fetching: BADM 372
# Cached: BADM 373
# Cached: BADM 374
# Cached: BADM 375
# Fetching: BADM 377
# Cached: BADM 378
# Cached: BADM 379
# Cached: BADM 380
# Cached: BADM 381
# Cached: BADM 382
# Cached: BADM 383
# Cached: BADM 390
# Cached: BADM 394
# Cached: BADM 395
# Cached: BADM 403
# Cached: BADM 420
# Cached: BADM 445
# Cached: BADM 446
# Fetching: BADM 447
# Cached: BADM 449
# Cached: BADM 453
# Fetching: BADM 458
# Fetching: BADM 460
# Cached: BADM 461
# Cached: BADM 463
# Fetching: BADM 464
# Fetching: BADM 501
# Fetching: BADM 502
# Fetching: BADM 503
# Fetching: BADM 504
# Fetching: BADM 507
# Cached: BADM 508
# Cached: BADM 509
# Fetching: BADM 510
# Cached: BADM 512
# Fetching: BADM 513
# Fetching: BADM 514
# Fetching: BADM 515
# Cached: BADM 516
# Fetching: BADM 519
# Cached: BADM 520
# Fetching: BADM 521
# Fetching: BADM 522
# Cached: BADM 523
# Cached: BADM 524
# Cached: BADM 525
# Cached: BADM 526
# Cached: BADM 527
# Fetching: BADM 528
# Fetching: BADM 529
# Fetching: BADM 531
# Fetching: BADM 532
# Fetching: BADM 533
# Cached: BADM 534
# Fetching: BADM 535
# Cached: BADM 537
# Fetching: BADM 538
# Fetching: BADM 539
# Fetching: BADM 540
# Cached: BADM 541
# Cached: BADM 543
# Cached: BADM 544
# Cached: BADM 545
# Fetching: BADM 546
# Cached: BADM 547
# Fetching: BADM 548
# Fetching: BADM 549
# Cached: BADM 550
# Fetching: BADM 551
# Fetching: BADM 552
# Fetching: BADM 553
# Cached: BADM 554
# Cached: BADM 555
# Cached: BADM 557
# Cached: BADM 558
# Fetching: BADM 559
# Cached: BADM 561
# Fetching: BADM 562
# Fetching: BADM 563
# Fetching: BADM 564
# Fetching: BADM 565
# Cached: BADM 566
# Cached: BADM 567
# Fetching: BADM 569
# Fetching: BADM 571
# Cached: BADM 572
# Cached: BADM 573
# Fetching: BADM 574
# Cached: BADM 575
# Cached: BADM 576
# Fetching: BADM 577
# Cached: BADM 578
# Fetching: BADM 579
# Cached: BADM 582
# Fetching: BADM 583
# Cached: BADM 584
# Fetching: BADM 586
# Cached: BADM 588
# Cached: BADM 589
# Cached: BADM 590
# Cached: BADM 591
# Cached: BADM 593
# Cached: BADM 594
# Fetching: BADM 595
# Fetching: BADM 599
# 31: BADM
# Fetching: BASQ 401
# Cached: BASQ 402
# 32: BASQ
# Fetching: BCOG 100
# Cached: BCOG 200
# Fetching: BCOG 301
# Fetching: BCOG 458
# Fetching: BCOG 492
# 33: BCOG
# Fetching: BCS 101
# Fetching: BCS 102
# Cached: BCS 115
# Cached: BCS 199
# Fetching: BCS 201
# Cached: BCS 202
# Fetching: BCS 215
# Fetching: BCS 301
# Fetching: BCS 302
# 34: BCS
# Cached: BDI 199
# Cached: BDI 367
# Fetching: BDI 411
# Cached: BDI 475
# Fetching: BDI 477
# Cached: BDI 513
# Cached: BDI 577
# Fetching: BDI 593
# 35: BDI
# Fetching: BIOC 190
# Cached: BIOC 199
# Cached: BIOC 290
# Cached: BIOC 406
# Cached: BIOC 446
# Cached: BIOC 455
# Fetching: BIOC 460
# Cached: BIOC 492
# Fetching: BIOC 555
# Cached: BIOC 590
# Cached: BIOC 595
# Cached: BIOC 599
# 36: BIOC
# Fetching: BIOE 100
# Cached: BIOE 120
# Fetching: BIOE 198
# Fetching: BIOE 199
# Cached: BIOE 200
# Fetching: BIOE 201
# Cached: BIOE 202
# Cached: BIOE 205
# Fetching: BIOE 206
# Cached: BIOE 210
# Cached: BIOE 297
# Fetching: BIOE 298
# Fetching: BIOE 302
# Cached: BIOE 303
# Fetching: BIOE 306
# Cached: BIOE 310
# Cached: BIOE 360
# Fetching: BIOE 380
# Cached: BIOE 397
# Fetching: BIOE 398
# Cached: BIOE 400
# Fetching: BIOE 404
# Cached: BIOE 414
# Cached: BIOE 415
# Cached: BIOE 416
# Fetching: BIOE 420
# Fetching: BIOE 424
# Fetching: BIOE 427
# Fetching: BIOE 430
# Cached: BIOE 432
# Cached: BIOE 434
# Fetching: BIOE 450
# Fetching: BIOE 460
# Fetching: BIOE 461
# Cached: BIOE 467
# Fetching: BIOE 476
# Cached: BIOE 479
# Cached: BIOE 480
# Cached: BIOE 481
# Fetching: BIOE 482
# Fetching: BIOE 483
# Cached: BIOE 484
# Fetching: BIOE 485
# Cached: BIOE 486
# Cached: BIOE 487
# Fetching: BIOE 488
# Fetching: BIOE 489
# Cached: BIOE 497
# Cached: BIOE 498
# Cached: BIOE 499
# Cached: BIOE 500
# Fetching: BIOE 501
# Fetching: BIOE 502
# Fetching: BIOE 504
# Fetching: BIOE 505
# Fetching: BIOE 507
# Fetching: BIOE 510
# Fetching: BIOE 516
# Cached: BIOE 526
# Cached: BIOE 570
# Fetching: BIOE 571
# Cached: BIOE 572
# Fetching: BIOE 573
# Cached: BIOE 574
# Cached: BIOE 575
# Cached: BIOE 580
# Fetching: BIOE 586
# Cached: BIOE 588
# Fetching: BIOE 589
# Cached: BIOE 597
# Cached: BIOE 598
# Fetching: BIOE 599
# 37: BIOE
# Fetching: BIOP 401
# Fetching: BIOP 419
# Cached: BIOP 432
# Fetching: BIOP 550
# Fetching: BIOP 576
# Fetching: BIOP 581
# Fetching: BIOP 582
# Fetching: BIOP 583
# Cached: BIOP 586
# Cached: BIOP 590
# Cached: BIOP 595
# Cached: BIOP 599
# 38: BIOP
# Fetching: BSE 600
# Cached: BSE 602
# Fetching: BSE 603
# Fetching: BSE 612
# Fetching: BSE 631
# Fetching: BSE 632
# Fetching: BSE 633
# Fetching: BSE 634
# Fetching: BSE 635
# Fetching: BSE 636
# Fetching: BSE 638
# Fetching: BSE 642
# Fetching: BSE 644
# Fetching: BSE 645
# Cached: BSE 655
# Cached: BSE 660
# Cached: BSE 666
# Fetching: BSE 680
# Fetching: BSE 685
# Fetching: BSE 686
# Cached: BSE 700
# Cached: BSE 701
# Cached: BSE 702
# Cached: BSE 703
# Cached: BSE 704
# Cached: BSE 705
# Cached: BSE 706
# Cached: BSE 707
# Cached: BSE 708
# Fetching: BSE 709
# Cached: BSE 710
# Cached: BSE 711
# Fetching: BSE 712
# Cached: BSE 720
# Cached: BSE 721
# Cached: BSE 730
# Cached: BSE 732
# Cached: BSE 733
# Cached: BSE 734
# Cached: BSE 735
# Cached: BSE 736
# Cached: BSE 737
# Cached: BSE 738
# Cached: BSE 739
# Cached: BSE 740
# Cached: BSE 741
# Fetching: BSE 742
# Cached: BSE 743
# Cached: BSE 744
# Cached: BSE 745
# Fetching: BSE 746
# Cached: BSE 747
# Cached: BSE 748
# Cached: BSE 749
# Cached: BSE 750
# Fetching: BSE 751
# Fetching: BSE 752
# Fetching: BSE 770
# Fetching: BSE 799
# 39: BSE
# Cached: BTW 199
# Cached: BTW 250
# Cached: BTW 261
# Cached: BTW 263
# Fetching: BTW 271
# Cached: BTW 279
# Cached: BTW 290
# Fetching: BTW 360
# Cached: BTW 380
# Cached: BTW 402
# Fetching: BTW 490
# 40: BTW
# Fetching: BUS 101
# Fetching: BUS 115
# Fetching: BUS 116
# Cached: BUS 199
# Cached: BUS 201
# Fetching: BUS 215
# Cached: BUS 299
# Cached: BUS 301
# Cached: BUS 302
# Fetching: BUS 315
# Cached: BUS 399
# Cached: BUS 401
# Fetching: BUS 402
# Fetching: BUS 415
# 41: BUS
# Cached: CAS 587
# 42: CAS
# Cached: CB 290
# Fetching: CB 420
# Fetching: CB 449
# Fetching: CB 467
# Fetching: CB 514
# Fetching: CB 516
# Fetching: CB 520
# Fetching: CB 533
# Fetching: CB 550
# Fetching: CB 551
# Fetching: CB 552
# Fetching: CB 554
# Fetching: CB 564
# Cached: CB 590
# Cached: CB 591
# Cached: CB 592
# Fetching: CB 594
# Cached: CB 596
# Fetching: CB 599
# Fetching: CB 646
# Cached: CB 692
# 43: CB
# Cached: CDB 590
# Cached: CDB 595
# Cached: CDB 599
# 44: CDB
# Fetching: CEE 190
# Fetching: CEE 198
# Fetching: CEE 199
# Cached: CEE 201
# Cached: CEE 202
# Cached: CEE 300
# Cached: CEE 310
# Cached: CEE 320
# Cached: CEE 330
# Fetching: CEE 331
# Fetching: CEE 340
# Cached: CEE 350
# Cached: CEE 360
# Cached: CEE 380
# Fetching: CEE 398
# Fetching: CEE 401
# Fetching: CEE 405
# Fetching: CEE 406
# Fetching: CEE 407
# Fetching: CEE 408
# Fetching: CEE 409
# Cached: CEE 410
# Cached: CEE 411
# Fetching: CEE 412
# Cached: CEE 415
# Fetching: CEE 416
# Fetching: CEE 417
# Cached: CEE 418
# Cached: CEE 419
# Cached: CEE 420
# Cached: CEE 421
# Fetching: CEE 422
# Fetching: CEE 433
# Fetching: CEE 434
# Fetching: CEE 435
# Cached: CEE 437
# Cached: CEE 438
# Cached: CEE 440
# Fetching: CEE 441
# Fetching: CEE 442
# Fetching: CEE 443
# Fetching: CEE 444
# Fetching: CEE 447
# Cached: CEE 449
# Fetching: CEE 450
# Fetching: CEE 451
# Cached: CEE 452
# Cached: CEE 453
# Fetching: CEE 457
# Fetching: CEE 458
# Fetching: CEE 459
# Cached: CEE 460
# Cached: CEE 461
# Cached: CEE 462
# Fetching: CEE 463
# Cached: CEE 465
# Fetching: CEE 467
# Fetching: CEE 468
# Fetching: CEE 469
# Cached: CEE 470
# Fetching: CEE 471
# Fetching: CEE 472
# Fetching: CEE 473
# Fetching: CEE 474
# Cached: CEE 483
# Cached: CEE 484
# Cached: CEE 490
# Cached: CEE 491
# Fetching: CEE 492
# Fetching: CEE 493
# Fetching: CEE 495
# Cached: CEE 497
# Cached: CEE 498
# Fetching: CEE 502
# Fetching: CEE 503
# Fetching: CEE 504
# Fetching: CEE 505
# Fetching: CEE 506
# Fetching: CEE 508
# Fetching: CEE 509
# Fetching: CEE 511
# Fetching: CEE 512
# Fetching: CEE 515
# Fetching: CEE 517
# Fetching: CEE 521
# Fetching: CEE 522
# Fetching: CEE 524
# Fetching: CEE 526
# Fetching: CEE 528
# Fetching: CEE 537
# Cached: CEE 538
# Fetching: CEE 543
# Fetching: CEE 544
# Fetching: CEE 545
# Fetching: CEE 549
# Fetching: CEE 551
# Cached: CEE 552
# Fetching: CEE 553
# Fetching: CEE 554
# Fetching: CEE 555
# Fetching: CEE 556
# Fetching: CEE 557
# Fetching: CEE 558
# Fetching: CEE 559
# Fetching: CEE 560
# Cached: CEE 562
# Cached: CEE 570
# Fetching: CEE 571
# Cached: CEE 572
# Cached: CEE 573
# Fetching: CEE 574
# Fetching: CEE 575
# Fetching: CEE 576
# Cached: CEE 577
# Fetching: CEE 578
# Fetching: CEE 580
# Fetching: CEE 581
# Fetching: CEE 582
# Fetching: CEE 583
# Fetching: CEE 585
# Fetching: CEE 586
# Fetching: CEE 587
# Fetching: CEE 588
# Fetching: CEE 589
# Fetching: CEE 590
# Fetching: CEE 591
# Cached: CEE 592
# Fetching: CEE 593
# Cached: CEE 595
# Cached: CEE 597
# Cached: CEE 598
# Fetching: CEE 599
# 45: CEE
# Fetching: CHBE 101
# Cached: CHBE 121
# Cached: CHBE 199
# Cached: CHBE 202
# Cached: CHBE 210
# Cached: CHBE 221
# Cached: CHBE 297
# Cached: CHBE 321
# Cached: CHBE 397
# Cached: CHBE 411
# Fetching: CHBE 412
# Cached: CHBE 413
# Fetching: CHBE 415
# Cached: CHBE 421
# Cached: CHBE 422
# Cached: CHBE 424
# Cached: CHBE 430
# Cached: CHBE 431
# Cached: CHBE 440
# Fetching: CHBE 451
# Cached: CHBE 453
# Fetching: CHBE 454
# Fetching: CHBE 455
# Fetching: CHBE 458
# Fetching: CHBE 459
# Cached: CHBE 461
# Fetching: CHBE 471
# Fetching: CHBE 472
# Fetching: CHBE 473
# Fetching: CHBE 474
# Cached: CHBE 475
# Fetching: CHBE 476
# Fetching: CHBE 478
# Cached: CHBE 481
# Cached: CHBE 494
# Fetching: CHBE 496
# Cached: CHBE 497
# Cached: CHBE 499
# Cached: CHBE 510
# Cached: CHBE 513
# Fetching: CHBE 521
# Cached: CHBE 522
# Cached: CHBE 523
# Fetching: CHBE 525
# Fetching: CHBE 551
# Fetching: CHBE 553
# Cached: CHBE 565
# Cached: CHBE 571
# Fetching: CHBE 581
# Cached: CHBE 582
# Cached: CHBE 593
# Cached: CHBE 594
# Cached: CHBE 597
# Cached: CHBE 598
# Fetching: CHBE 599
# 46: CHBE
# Cached: CHEM 101
# Cached: CHEM 102
# Cached: CHEM 103
# Cached: CHEM 104
# Cached: CHEM 105
# Cached: CHEM 108
# Fetching: CHEM 150
# Cached: CHEM 197
# Cached: CHEM 199
# Fetching: CHEM 202
# Fetching: CHEM 203
# Cached: CHEM 204
# Cached: CHEM 205
# Fetching: CHEM 222
# Fetching: CHEM 223
# Cached: CHEM 232
# Cached: CHEM 233
# Cached: CHEM 236
# Cached: CHEM 237
# Cached: CHEM 293
# Cached: CHEM 295
# Cached: CHEM 297
# Cached: CHEM 312
# Cached: CHEM 315
# Fetching: CHEM 317
# Cached: CHEM 332
# Cached: CHEM 360
# Cached: CHEM 397
# Cached: CHEM 420
# Cached: CHEM 436
# Cached: CHEM 437
# Cached: CHEM 440
# Cached: CHEM 442
# Cached: CHEM 444
# Cached: CHEM 445
# Cached: CHEM 447
# Cached: CHEM 452
# Fetching: CHEM 460
# Cached: CHEM 472
# Cached: CHEM 474
# Fetching: CHEM 480
# Cached: CHEM 482
# Cached: CHEM 483
# Fetching: CHEM 488
# Cached: CHEM 492
# Cached: CHEM 494
# Fetching: CHEM 495
# Cached: CHEM 497
# Cached: CHEM 499
# Fetching: CHEM 512
# Cached: CHEM 515
# Cached: CHEM 516
# Fetching: CHEM 517
# Fetching: CHEM 518
# Fetching: CHEM 520
# Fetching: CHEM 522
# Cached: CHEM 524
# Cached: CHEM 525
# Cached: CHEM 530
# Fetching: CHEM 532
# Fetching: CHEM 534
# Cached: CHEM 535
# Fetching: CHEM 538
# Fetching: CHEM 540
# Cached: CHEM 542
# Fetching: CHEM 544
# Cached: CHEM 545
# Fetching: CHEM 546
# Fetching: CHEM 548
# Cached: CHEM 550
# Fetching: CHEM 570
# Cached: CHEM 572
# Cached: CHEM 575
# Fetching: CHEM 576
# Fetching: CHEM 582
# Fetching: CHEM 584
# Cached: CHEM 585
# Fetching: CHEM 586
# Cached: CHEM 588
# Cached: CHEM 590
# Fetching: CHEM 591
# Fetching: CHEM 592
# Cached: CHEM 593
# Cached: CHEM 595
# Cached: CHEM 599
# 47: CHEM
# Fetching: CHIN 199
# Fetching: CHIN 201
# Cached: CHIN 202
# Fetching: CHIN 203
# Cached: CHIN 204
# Fetching: CHIN 241
# Cached: CHIN 242
# Fetching: CHIN 305
# Cached: CHIN 306
# Fetching: CHIN 407
# Cached: CHIN 408
# Fetching: CHIN 409
# Fetching: CHIN 440
# Cached: CHIN 441
# Fetching: CHIN 490
# Fetching: CHIN 499
# 48: CHIN
# Fetching: CHP 199
# Cached: CHP 395
# Fetching: CHP 396
# 49: CHP
# Fetching: CI 199
# Cached: CI 205
# Cached: CI 210
# Cached: CI 211
# Fetching: CI 260
# Fetching: CI 312
# Cached: CI 317
# Fetching: CI 355
# Fetching: CI 380
# Cached: CI 382
# Cached: CI 395
# Cached: CI 401
# Fetching: CI 402
# Fetching: CI 403
# Cached: CI 404
# Fetching: CI 405
# Fetching: CI 406
# Cached: CI 407
# Fetching: CI 410
# Cached: CI 415
# Cached: CI 420
# Fetching: CI 421
# Fetching: CI 422
# Cached: CI 424
# Fetching: CI 425
# Fetching: CI 430
# Fetching: CI 431
# Cached: CI 432
# Fetching: CI 433
# Fetching: CI 434
# Cached: CI 435
# Fetching: CI 436
# Fetching: CI 437
# Cached: CI 438
# Fetching: CI 441
# Fetching: CI 442
# Cached: CI 443
# Fetching: CI 444
# Cached: CI 445
# Cached: CI 446
# Cached: CI 447
# Cached: CI 448
# Fetching: CI 449
# Fetching: CI 450
# Cached: CI 451
# Fetching: CI 452
# Cached: CI 453
# Cached: CI 454
# Cached: CI 455
# Cached: CI 456
# Cached: CI 465
# Cached: CI 466
# Fetching: CI 467
# Fetching: CI 468
# Fetching: CI 471
# Fetching: CI 472
# Cached: CI 473
# Fetching: CI 474
# Cached: CI 475
# Fetching: CI 476
# Cached: CI 477
# Fetching: CI 478
# Fetching: CI 479
# Fetching: CI 480
# Fetching: CI 482
# Fetching: CI 483
# Fetching: CI 485
# Fetching: CI 486
# Cached: CI 487
# Fetching: CI 488
# Cached: CI 489
# Fetching: CI 491
# Fetching: CI 492
# Fetching: CI 498
# Fetching: CI 499
# Cached: CI 501
# Fetching: CI 502
# Fetching: CI 503
# Fetching: CI 504
# Fetching: CI 505
# Fetching: CI 506
# Fetching: CI 507
# Fetching: CI 508
# Cached: CI 509
# Fetching: CI 511
# Fetching: CI 512
# Fetching: CI 513
# Fetching: CI 516
# Cached: CI 517
# Fetching: CI 518
# Fetching: CI 519
# Fetching: CI 520
# Fetching: CI 521
# Fetching: CI 522
# Fetching: CI 526
# Fetching: CI 530
# Fetching: CI 532
# Fetching: CI 533
# Fetching: CI 534
# Fetching: CI 535
# Fetching: CI 536
# Fetching: CI 537
# Fetching: CI 538
# Fetching: CI 539
# Fetching: CI 540
# Fetching: CI 541
# Fetching: CI 542
# Fetching: CI 543
# Fetching: CI 544
# Fetching: CI 545
# Fetching: CI 546
# Fetching: CI 547
# Fetching: CI 548
# Fetching: CI 550
# Fetching: CI 552
# Fetching: CI 553
# Fetching: CI 554
# Cached: CI 555
# Fetching: CI 556
# Cached: CI 557
# Fetching: CI 558
# Fetching: CI 560
# Fetching: CI 561
# Fetching: CI 562
# Fetching: CI 563
# Cached: CI 565
# Cached: CI 566
# Cached: CI 567
# Fetching: CI 568
# Fetching: CI 569
# Fetching: CI 570
# Fetching: CI 573
# Fetching: CI 575
# Fetching: CI 576
# Fetching: CI 577
# Fetching: CI 578
# Fetching: CI 580
# Fetching: CI 582
# Fetching: CI 584
# Fetching: CI 585
# Fetching: CI 586
# Fetching: CI 587
# Cached: CI 590
# Cached: CI 591
# Fetching: CI 592
# Fetching: CI 593
# Cached: CI 595
# Fetching: CI 599
# 50: CI
# Fetching: CIC 390
# Cached: CIC 500
# 51: CIC
# Cached: CLCV 100
# Cached: CLCV 102
# Cached: CLCV 111
# Cached: CLCV 114
# Cached: CLCV 115
# Cached: CLCV 116
# Cached: CLCV 120
# Fetching: CLCV 131
# Cached: CLCV 132
# Fetching: CLCV 133
# Fetching: CLCV 160
# Cached: CLCV 199
# Cached: CLCV 203
# Fetching: CLCV 206
# Fetching: CLCV 217
# Cached: CLCV 220
# Fetching: CLCV 221
# Cached: CLCV 224
# Fetching: CLCV 225
# Fetching: CLCV 230
# Cached: CLCV 231
# Fetching: CLCV 232
# Cached: CLCV 240
# Cached: CLCV 250
# Cached: CLCV 322
# Fetching: CLCV 323
# Fetching: CLCV 410
# Fetching: CLCV 411
# Fetching: CLCV 430
# Cached: CLCV 440
# Cached: CLCV 443
# Fetching: CLCV 444
# Fetching: CLCV 450
# Fetching: CLCV 490
# Cached: CLCV 491
# Cached: CLCV 492
# Fetching: CLCV 493
# Fetching: CLCV 515
# Fetching: CLCV 520
# Fetching: CLCV 550
# 52: CLCV
# Cached: CLE 610
# Fetching: CLE 613
# Fetching: CLE 614
# Cached: CLE 631
# Fetching: CLE 640
# Fetching: CLE 645
# Fetching: CLE 650
# Fetching: CLE 655
# Fetching: CLE 660
# Fetching: CLE 665
# Fetching: CLE 670
# Cached: CLE 675
# Fetching: CLE 680
# Cached: CLE 681
# Cached: CLE 683
# Cached: CLE 684
# Cached: CLE 685
# Cached: CLE 686
# Cached: CLE 687
# Cached: CLE 688
# Cached: CLE 689
# Cached: CLE 690
# Cached: CLE 692
# Cached: CLE 693
# Fetching: CLE 694
# Cached: CLE 695
# Cached: CLE 696
# Cached: CLE 697
# Fetching: CLE 698
# Cached: CLE 702
# Cached: CLE 704
# Fetching: CLE 705
# Cached: CLE 706
# Cached: CLE 707
# Fetching: CLE 708
# Fetching: CLE 710
# Cached: CLE 713
# Cached: CLE 714
# Cached: CLE 715
# Cached: CLE 716
# Cached: CLE 717
# Cached: CLE 718
# Cached: CLE 719
# Cached: CLE 720
# Cached: CLE 721
# Cached: CLE 730
# Cached: CLE 731
# Cached: CLE 732
# Cached: CLE 733
# Cached: CLE 736
# Cached: CLE 737
# Cached: CLE 738
# Cached: CLE 739
# Cached: CLE 740
# Cached: CLE 741
# Cached: CLE 742
# Cached: CLE 743
# Cached: CLE 744
# Cached: CLE 745
# Cached: CLE 746
# Cached: CLE 748
# Cached: CLE 750
# Cached: CLE 751
# Cached: CLE 752
# Cached: CLE 753
# Cached: CLE 764
# Cached: CLE 765
# Cached: CLE 767
# Fetching: CLE 770
# Cached: CLE 771
# Cached: CLE 772
# Cached: CLE 773
# Cached: CLE 774
# Cached: CLE 775
# Cached: CLE 776
# Cached: CLE 777
# Cached: CLE 778
# Cached: CLE 779
# Cached: CLE 780
# Cached: CLE 781
# Cached: CLE 782
# Cached: CLE 783
# Cached: CLE 784
# Cached: CLE 786
# Cached: CLE 788
# Cached: CLE 789
# Cached: CLE 790
# Cached: CLE 793
# Cached: CLE 794
# Cached: CLE 795
# Cached: CLE 796
# Cached: CLE 797
# Fetching: CLE 798
# Cached: CLE 799
# 53: CLE
# Cached: CMN 101
# Cached: CMN 102
# Fetching: CMN 111
# Cached: CMN 112
# Cached: CMN 199
# Cached: CMN 204
# Cached: CMN 210
# Cached: CMN 211
# Cached: CMN 212
# Cached: CMN 213
# Fetching: CMN 214
# Fetching: CMN 215
# Cached: CMN 220
# Cached: CMN 230
# Cached: CMN 232
# Cached: CMN 250
# Cached: CMN 260
# Fetching: CMN 274
# Cached: CMN 277
# Cached: CMN 280
# Cached: CMN 304
# Fetching: CMN 312
# Fetching: CMN 314
# Fetching: CMN 315
# Fetching: CMN 319
# Cached: CMN 321
# Cached: CMN 323
# Fetching: CMN 325
# Cached: CMN 326
# Fetching: CMN 327
# Cached: CMN 328
# Cached: CMN 336
# Fetching: CMN 338
# Cached: CMN 340
# Cached: CMN 345
# Fetching: CMN 357
# Cached: CMN 361
# Cached: CMN 368
# Cached: CMN 375
# Fetching: CMN 380
# Cached: CMN 390
# Cached: CMN 396
# Cached: CMN 410
# Cached: CMN 411
# Fetching: CMN 412
# Fetching: CMN 420
# Cached: CMN 421
# Fetching: CMN 423
# Fetching: CMN 424
# Fetching: CMN 425
# Fetching: CMN 429
# Cached: CMN 432
# Fetching: CMN 433
# Fetching: CMN 435
# Fetching: CMN 450
# Cached: CMN 462
# Fetching: CMN 464
# Fetching: CMN 465
# Cached: CMN 467
# Cached: CMN 491
# Cached: CMN 493
# Cached: CMN 496
# Fetching: CMN 501
# Fetching: CMN 502
# Fetching: CMN 503
# Cached: CMN 505
# Fetching: CMN 507
# Cached: CMN 508
# Cached: CMN 529
# Cached: CMN 538
# Fetching: CMN 550
# Fetching: CMN 574
# Cached: CMN 575
# Cached: CMN 595
# Fetching: CMN 599
# 54: CMN
# Fetching: CPSC 102
# Fetching: CPSC 103
# Fetching: CPSC 112
# Cached: CPSC 113
# Cached: CPSC 116
# Fetching: CPSC 117
# Fetching: CPSC 131
# Fetching: CPSC 140
# Cached: CPSC 180
# Fetching: CPSC 199
# Fetching: CPSC 212
# Fetching: CPSC 213
# Fetching: CPSC 215
# Cached: CPSC 241
# Cached: CPSC 261
# Cached: CPSC 265
# Fetching: CPSC 266
# Fetching: CPSC 270
# Cached: CPSC 304
# Fetching: CPSC 326
# Fetching: CPSC 336
# Fetching: CPSC 352
# Fetching: CPSC 370
# Fetching: CPSC 382
# Cached: CPSC 393
# Cached: CPSC 395
# Fetching: CPSC 396
# Fetching: CPSC 407
# Fetching: CPSC 408
# Fetching: CPSC 412
# Fetching: CPSC 413
# Cached: CPSC 414
# Fetching: CPSC 415
# Fetching: CPSC 416
# Cached: CPSC 418
# Fetching: CPSC 419
# Fetching: CPSC 426
# Cached: CPSC 428
# Cached: CPSC 431
# Fetching: CPSC 433
# Cached: CPSC 436
# Fetching: CPSC 437
# Fetching: CPSC 438
# Fetching: CPSC 439
# Cached: CPSC 440
# Fetching: CPSC 442
# Fetching: CPSC 444
# Fetching: CPSC 448
# Fetching: CPSC 452
# Cached: CPSC 453
# Fetching: CPSC 454
# Fetching: CPSC 466
# Fetching: CPSC 473
# Fetching: CPSC 479
# Cached: CPSC 480
# Cached: CPSC 481
# Fetching: CPSC 484
# Fetching: CPSC 485
# Fetching: CPSC 486
# Cached: CPSC 488
# Cached: CPSC 489
# Cached: CPSC 491
# Fetching: CPSC 498
# Cached: CPSC 499
# Fetching: CPSC 501
# Cached: CPSC 505
# Fetching: CPSC 508
# Cached: CPSC 518
# Fetching: CPSC 526
# Cached: CPSC 527
# Fetching: CPSC 538
# Cached: CPSC 540
# Fetching: CPSC 541
# Cached: CPSC 543
# Cached: CPSC 554
# Fetching: CPSC 555
# Fetching: CPSC 556
# Fetching: CPSC 563
# Fetching: CPSC 565
# Cached: CPSC 566
# Cached: CPSC 567
# Fetching: CPSC 569
# Fetching: CPSC 575
# Fetching: CPSC 588
# Cached: CPSC 591
# Cached: CPSC 593
# Fetching: CPSC 594
# Cached: CPSC 598
# Fetching: CPSC 599
# 55: CPSC
# Fetching: CS 100
# Cached: CS 101
# Cached: CS 102
# Cached: CS 105
# Cached: CS 107
# Cached: CS 124
# Fetching: CS 125
# Fetching: CS 126
# Cached: CS 128
# Cached: CS 173
# Fetching: CS 196
# Cached: CS 199
# Cached: CS 210
# Cached: CS 211
# Cached: CS 222
# Cached: CS 225
# Cached: CS 233
# Fetching: CS 242
# Fetching: CS 265
# Cached: CS 266
# Cached: CS 277
# Fetching: CS 296
# Cached: CS 307
# Cached: CS 340
# Cached: CS 341
# Cached: CS 357
# Cached: CS 361
# Cached: CS 374
# Cached: CS 397
# Fetching: CS 398
# Fetching: CS 400
# Fetching: CS 401
# Cached: CS 402
# Cached: CS 403
# Cached: CS 407
# Fetching: CS 409
# Cached: CS 410
# Cached: CS 411
# Cached: CS 412
# Cached: CS 413
# Fetching: CS 414
# Cached: CS 415
# Fetching: CS 416
# Cached: CS 417
# Fetching: CS 418
# Fetching: CS 419
# Fetching: CS 420
# Cached: CS 421
# Fetching: CS 422
# Cached: CS 423
# Fetching: CS 424
# Cached: CS 425
# Fetching: CS 426
# Cached: CS 427
# Fetching: CS 428
# Fetching: CS 429
# Cached: CS 431
# Cached: CS 433
# Cached: CS 434
# Cached: CS 435
# Fetching: CS 436
# Cached: CS 437
# Cached: CS 438
# Fetching: CS 439
# Cached: CS 440
# Cached: CS 441
# Cached: CS 442
# Cached: CS 443
# Cached: CS 444
# Cached: CS 445
# Cached: CS 446
# Fetching: CS 447
# Cached: CS 448
# Cached: CS 450
# Fetching: CS 452
# Fetching: CS 460
# Cached: CS 461
# Cached: CS 462
# Cached: CS 463
# Cached: CS 464
# Fetching: CS 465
# Cached: CS 466
# Fetching: CS 467
# Cached: CS 468
# Fetching: CS 469
# Fetching: CS 470
# Cached: CS 473
# Fetching: CS 474
# Fetching: CS 475
# Cached: CS 476
# Cached: CS 477
# Fetching: CS 481
# Cached: CS 482
# Cached: CS 483
# Fetching: CS 484
# Cached: CS 491
# Fetching: CS 492
# Fetching: CS 493
# Fetching: CS 494
# Cached: CS 497
# Cached: CS 498
# Cached: CS 499
# Fetching: CS 500
# Cached: CS 507
# Fetching: CS 508
# Cached: CS 510
# Fetching: CS 511
# Cached: CS 512
# Fetching: CS 513
# Fetching: CS 514
# Fetching: CS 519
# Cached: CS 521
# Fetching: CS 522
# Cached: CS 523
# Fetching: CS 524
# Cached: CS 525
# Cached: CS 526
# Cached: CS 527
# Cached: CS 533
# Cached: CS 534
# Fetching: CS 536
# Cached: CS 537
# Fetching: CS 538
# Fetching: CS 539
# Fetching: CS 540
# Fetching: CS 541
# Fetching: CS 542
# Cached: CS 543
# Fetching: CS 544
# Fetching: CS 545
# Fetching: CS 546
# Fetching: CS 547
# Fetching: CS 549
# Cached: CS 554
# Cached: CS 555
# Fetching: CS 556
# Fetching: CS 558
# Cached: CS 562
# Cached: CS 563
# Cached: CS 565
# Fetching: CS 567
# Cached: CS 568
# Fetching: CS 571
# Fetching: CS 572
# Fetching: CS 574
# Fetching: CS 575
# Cached: CS 576
# Fetching: CS 579
# Fetching: CS 580
# Cached: CS 581
# Fetching: CS 582
# Cached: CS 583
# Cached: CS 584
# Fetching: CS 585
# Fetching: CS 586
# Cached: CS 588
# Cached: CS 591
# Cached: CS 597
# Cached: CS 598
# Fetching: CS 599
# 56: CS
# Fetching: CSE 198
# Fetching: CSE 298
# Fetching: CSE 398
# Cached: CSE 401
# Fetching: CSE 402
# Cached: CSE 408
# Cached: CSE 412
# Cached: CSE 414
# Cached: CSE 422
# Cached: CSE 423
# Cached: CSE 426
# Fetching: CSE 427
# Cached: CSE 428
# Fetching: CSE 429
# Cached: CSE 440
# Cached: CSE 441
# Cached: CSE 448
# Fetching: CSE 450
# Cached: CSE 451
# Cached: CSE 461
# Fetching: CSE 485
# ...
# Fetching: SLAV 505
# Fetching: SLAV 525
# Fetching: SLAV 575
# Fetching: SLAV 576
# Fetching: SLAV 577
# Cached: SLAV 591
# Fetching: SLAV 599
# 165: SLAV
# Cached: SLCL 110
# Fetching: SLCL 200
# Fetching: SLCL 300
# Fetching: SLCL 520
# 166: SLCL
# Cached: SOC 100
# Cached: SOC 101
# Cached: SOC 130
# Cached: SOC 160
# Fetching: SOC 161
# Fetching: SOC 163
# Cached: SOC 180
# Cached: SOC 196
# Cached: SOC 199
# Cached: SOC 200
# Cached: SOC 201
# Fetching: SOC 202
# Cached: SOC 221
# Cached: SOC 222
# Cached: SOC 223
# Cached: SOC 225
# Fetching: SOC 226
# Fetching: SOC 230
# Fetching: SOC 255
# Fetching: SOC 265
# Fetching: SOC 270
# Fetching: SOC 273
# Cached: SOC 274
# Cached: SOC 275
# Fetching: SOC 278
# Cached: SOC 280
# Cached: SOC 310
# Fetching: SOC 320
# Fetching: SOC 321
# Fetching: SOC 322
# Fetching: SOC 324
# Cached: SOC 325
# Fetching: SOC 345
# Cached: SOC 350
# Cached: SOC 355
# Fetching: SOC 364
# Cached: SOC 373
# Cached: SOC 375
# Cached: SOC 380
# Fetching: SOC 387
# Cached: SOC 390
# Fetching: SOC 392
# Cached: SOC 396
# Cached: SOC 400
# Fetching: SOC 447
# Cached: SOC 450
# Fetching: SOC 451
# Fetching: SOC 470
# Fetching: SOC 472
# Fetching: SOC 473
# Fetching: SOC 478
# Cached: SOC 479
# Fetching: SOC 480
# Fetching: SOC 483
# Cached: SOC 490
# Cached: SOC 495
# Fetching: SOC 496
# Fetching: SOC 500
# Cached: SOC 501
# Cached: SOC 510
# Fetching: SOC 561
# Fetching: SOC 563
# Fetching: SOC 564
# Fetching: SOC 565
# Fetching: SOC 572
# Fetching: SOC 575
# Fetching: SOC 576
# Fetching: SOC 578
# Fetching: SOC 579
# Fetching: SOC 583
# Fetching: SOC 584
# Cached: SOC 586
# Fetching: SOC 588
# Cached: SOC 590
# Cached: SOC 596
# Cached: SOC 597
# Cached: SOC 598
# Fetching: SOC 599
# 167: SOC
# Fetching: SOCW 101
# Cached: SOCW 199
# Cached: SOCW 200
# Fetching: SOCW 220
# Cached: SOCW 225
# Cached: SOCW 235
# Cached: SOCW 240
# Fetching: SOCW 245
# Cached: SOCW 297
# Fetching: SOCW 298
# Cached: SOCW 299
# Cached: SOCW 300
# Cached: SOCW 310
# Fetching: SOCW 315
# Cached: SOCW 321
# Cached: SOCW 322
# Fetching: SOCW 325
# Cached: SOCW 330
# Fetching: SOCW 335
# Cached: SOCW 360
# Cached: SOCW 370
# Fetching: SOCW 380
# Fetching: SOCW 400
# Cached: SOCW 401
# Cached: SOCW 402
# Cached: SOCW 403
# Cached: SOCW 404
# Cached: SOCW 410
# Cached: SOCW 412
# Cached: SOCW 416
# Cached: SOCW 417
# Cached: SOCW 418
# Fetching: SOCW 420
# Fetching: SOCW 425
# Cached: SOCW 427
# Fetching: SOCW 436
# Fetching: SOCW 445
# Cached: SOCW 451
# Fetching: SOCW 455
# Cached: SOCW 456
# Cached: SOCW 461
# Cached: SOCW 470
# Fetching: SOCW 473
# Fetching: SOCW 475
# Cached: SOCW 480
# Cached: SOCW 500
# Fetching: SOCW 501
# Fetching: SOCW 502
# Cached: SOCW 503
# Fetching: SOCW 504
# Cached: SOCW 505
# Fetching: SOCW 506
# Cached: SOCW 507
# Cached: SOCW 508
# Cached: SOCW 509
# Cached: SOCW 510
# Fetching: SOCW 513
# Cached: SOCW 514
# Cached: SOCW 515
# Cached: SOCW 516
# Cached: SOCW 519
# Fetching: SOCW 520
# Fetching: SOCW 521
# Fetching: SOCW 522
# Fetching: SOCW 525
# Cached: SOCW 526
# Cached: SOCW 531
# Cached: SOCW 532
# Cached: SOCW 533
# Cached: SOCW 541
# Cached: SOCW 542
# Cached: SOCW 552
# Cached: SOCW 553
# Fetching: SOCW 554
# Cached: SOCW 561
# Fetching: SOCW 562
# Fetching: SOCW 575
# Fetching: SOCW 576
# Cached: SOCW 579
# Cached: SOCW 580
# Cached: SOCW 581
# Cached: SOCW 584
# Fetching: SOCW 585
# Cached: SOCW 589
# Fetching: SOCW 593
# Cached: SOCW 594
# Cached: SOCW 595
# Fetching: SOCW 599
# 168: SOCW
# Cached: SPAN 101
# Cached: SPAN 102
# Cached: SPAN 122
# Cached: SPAN 130
# Cached: SPAN 141
# Cached: SPAN 142
# Fetching: SPAN 150
# Cached: SPAN 199
# Cached: SPAN 200
# Fetching: SPAN 202
# Cached: SPAN 204
# Cached: SPAN 208
# Cached: SPAN 228
# Cached: SPAN 232
# Cached: SPAN 240
# Cached: SPAN 242
# Cached: SPAN 246
# Cached: SPAN 248
# Cached: SPAN 250
# Cached: SPAN 252
# Cached: SPAN 254
# Fetching: SPAN 295
# Fetching: SPAN 299
# Cached: SPAN 303
# Cached: SPAN 305
# Cached: SPAN 307
# Cached: SPAN 308
# Cached: SPAN 309
# Fetching: SPAN 310
# Cached: SPAN 312
# Fetching: SPAN 316
# Fetching: SPAN 318
# Cached: SPAN 320
# Fetching: SPAN 324
# Cached: SPAN 326
# Fetching: SPAN 330
# Cached: SPAN 332
# Fetching: SPAN 395
# Cached: SPAN 399
# Fetching: SPAN 410
# Cached: SPAN 418
# Fetching: SPAN 430
# Fetching: SPAN 431
# Fetching: SPAN 432
# Fetching: SPAN 433
# Fetching: SPAN 434
# Fetching: SPAN 435
# Fetching: SPAN 436
# Fetching: SPAN 437
# Fetching: SPAN 442
# Cached: SPAN 460
# Fetching: SPAN 462
# Cached: SPAN 463
# Fetching: SPAN 464
# Fetching: SPAN 465
# Cached: SPAN 466
# Fetching: SPAN 467
# Fetching: SPAN 468
# Fetching: SPAN 477
# Cached: SPAN 489
# Cached: SPAN 490
# Cached: SPAN 491
# Fetching: SPAN 528
# Cached: SPAN 535
# Fetching: SPAN 557
# Fetching: SPAN 558
# Fetching: SPAN 559
# Fetching: SPAN 571
# Fetching: SPAN 572
# Fetching: SPAN 580
# Fetching: SPAN 584
# Cached: SPAN 588
# Cached: SPAN 590
# Cached: SPAN 595
# Cached: SPAN 599
# 169: SPAN
# Cached: SPED 117
# Cached: SPED 199
# Fetching: SPED 312
# Fetching: SPED 317
# Cached: SPED 322
# Cached: SPED 391
# Cached: SPED 395
# Fetching: SPED 405
# Cached: SPED 410
# Cached: SPED 412
# Fetching: SPED 414
# Fetching: SPED 418
# Fetching: SPED 424
# Cached: SPED 426
# Fetching: SPED 431
# Fetching: SPED 432
# Fetching: SPED 435
# Fetching: SPED 436
# Fetching: SPED 437
# Cached: SPED 438
# Fetching: SPED 440
# Fetching: SPED 441
# Cached: SPED 442
# Fetching: SPED 443
# Fetching: SPED 444
# Fetching: SPED 446
# Fetching: SPED 447
# Fetching: SPED 448
# Fetching: SPED 450
# Cached: SPED 452
# Fetching: SPED 453
# Fetching: SPED 460
# Fetching: SPED 461
# Cached: SPED 462
# Fetching: SPED 465
# Fetching: SPED 470
# Cached: SPED 471
# Fetching: SPED 488
# Fetching: SPED 501
# Fetching: SPED 503
# Cached: SPED 505
# Cached: SPED 507
# Fetching: SPED 510
# Fetching: SPED 514
# Fetching: SPED 517
# Fetching: SPED 521
# Cached: SPED 524
# Fetching: SPED 525
# Cached: SPED 526
# Fetching: SPED 538
# Fetching: SPED 550
# Fetching: SPED 556
# Fetching: SPED 565
# Cached: SPED 566
# Cached: SPED 575
# Cached: SPED 583
# Cached: SPED 585
# Cached: SPED 590
# Cached: SPED 591
# Fetching: SPED 592
# Cached: SPED 593
# Cached: SPED 595
# Fetching: SPED 599
# 170: SPED
# Cached: STAT 100
# Cached: STAT 107
# Cached: STAT 199
# Cached: STAT 200
# Cached: STAT 207
# Cached: STAT 212
# Cached: STAT 361
# Cached: STAT 385
# Cached: STAT 390
# Cached: STAT 391
# Cached: STAT 400
# Cached: STAT 408
# Fetching: STAT 409
# Cached: STAT 410
# Cached: STAT 420
# Fetching: STAT 424
# Cached: STAT 425
# Cached: STAT 426
# Cached: STAT 427
# Cached: STAT 428
# Cached: STAT 429
# Cached: STAT 430
# Cached: STAT 431
# Cached: STAT 432
# Cached: STAT 433
# Cached: STAT 434
# Cached: STAT 437
# Cached: STAT 440
# Fetching: STAT 441
# Cached: STAT 443
# Cached: STAT 447
# Cached: STAT 448
# Fetching: STAT 463
# Fetching: STAT 480
# Cached: STAT 510
# Fetching: STAT 511
# Cached: STAT 525
# Fetching: STAT 527
# Cached: STAT 528
# Cached: STAT 530
# Fetching: STAT 533
# Cached: STAT 541
# Cached: STAT 542
# Cached: STAT 543
# Fetching: STAT 545
# Fetching: STAT 546
# Cached: STAT 551
# Fetching: STAT 552
# Fetching: STAT 553
# Fetching: STAT 554
# Fetching: STAT 555
# Fetching: STAT 556
# Fetching: STAT 558
# Fetching: STAT 571
# Cached: STAT 575
# Fetching: STAT 576
# Cached: STAT 578
# Cached: STAT 587
# Fetching: STAT 588
# Cached: STAT 590
# Cached: STAT 593
# Fetching: STAT 595
# Fetching: STAT 599
# 171: STAT
# Fetching: SWAH 199
# Fetching: SWAH 201
# Cached: SWAH 202
# Fetching: SWAH 403
# Cached: SWAH 404
# Fetching: SWAH 405
# Cached: SWAH 406
# Fetching: SWAH 407
# Fetching: SWAH 408
# Fetching: SWAH 409
# Fetching: SWAH 410
# 172: SWAH
# Fetching: TAM 195
# Cached: TAM 199
# Fetching: TAM 201
# Cached: TAM 210
# Cached: TAM 211
# Cached: TAM 212
# Cached: TAM 251
# Cached: TAM 252
# Cached: TAM 270
# Cached: TAM 297
# Cached: TAM 324
# Cached: TAM 335
# Cached: TAM 412
# Fetching: TAM 413
# Fetching: TAM 416
# Fetching: TAM 424
# Fetching: TAM 428
# Fetching: TAM 435
# Cached: TAM 445
# Fetching: TAM 451
# Cached: TAM 456
# Fetching: TAM 461
# Fetching: TAM 470
# Cached: TAM 497
# Cached: TAM 498
# Cached: TAM 500
# Fetching: TAM 514
# Fetching: TAM 516
# Fetching: TAM 518
# Fetching: TAM 524
# Fetching: TAM 529
# Fetching: TAM 531
# Cached: TAM 532
# Cached: TAM 534
# Cached: TAM 536
# Fetching: TAM 537
# Fetching: TAM 538
# Cached: TAM 539
# Fetching: TAM 541
# Cached: TAM 542
# Fetching: TAM 545
# Fetching: TAM 549
# Fetching: TAM 551
# Cached: TAM 552
# Fetching: TAM 554
# Fetching: TAM 555
# Fetching: TAM 557
# Fetching: TAM 559
# Cached: TAM 561
# Fetching: TAM 570
# Fetching: TAM 574
# Cached: TAM 597
# Fetching: TAM 598
# Fetching: TAM 599
# 173: TAM
# Cached: TE 100
# Fetching: TE 110
# Cached: TE 198
# Fetching: TE 200
# Fetching: TE 230
# Cached: TE 250
# Fetching: TE 260
# Fetching: TE 298
# Cached: TE 333
# Fetching: TE 350
# Cached: TE 360
# Cached: TE 390
# Fetching: TE 398
# Cached: TE 401
# Cached: TE 440
# Fetching: TE 441
# Cached: TE 450
# Cached: TE 460
# Cached: TE 461
# Cached: TE 462
# Cached: TE 466
# Cached: TE 468
# Fetching: TE 497
# Fetching: TE 498
# Cached: TE 510
# Fetching: TE 560
# Cached: TE 565
# Cached: TE 566
# Cached: TE 567
# Cached: TE 598
# 174: TE
# Cached: THEA 100
# Cached: THEA 101
# Cached: THEA 110
# Cached: THEA 119
# Fetching: THEA 121
# Cached: THEA 122
# Fetching: THEA 123
# Fetching: THEA 126
# Fetching: THEA 151
# Cached: THEA 153
# Cached: THEA 170
# Cached: THEA 175
# Cached: THEA 199
# Cached: THEA 200
# Fetching: THEA 204
# Cached: THEA 208
# Fetching: THEA 209
# Fetching: THEA 211
# Cached: THEA 212
# Fetching: THEA 218
# Fetching: THEA 220
# Cached: THEA 222
# Cached: THEA 223
# Fetching: THEA 225
# Cached: THEA 231
# Fetching: THEA 242
# Fetching: THEA 243
# Fetching: THEA 260
# Fetching: THEA 263
# Fetching: THEA 270
# Fetching: THEA 271
# Cached: THEA 275
# Cached: THEA 276
# Fetching: THEA 284
# Cached: THEA 300
# Cached: THEA 304
# Fetching: THEA 323
# Cached: THEA 359
# Fetching: THEA 360
# Fetching: THEA 361
# Fetching: THEA 362
# Fetching: THEA 364
# Fetching: THEA 371
# Fetching: THEA 372
# Fetching: THEA 373
# Fetching: THEA 374
# Cached: THEA 375
# Cached: THEA 376
# Cached: THEA 377
# Cached: THEA 378
# Cached: THEA 384
# Cached: THEA 385
# Cached: THEA 391
# Cached: THEA 392
# Cached: THEA 399
# Cached: THEA 400
# Fetching: THEA 401
# Fetching: THEA 402
# Fetching: THEA 403
# Fetching: THEA 404
# Cached: THEA 405
# Cached: THEA 406
# Fetching: THEA 407
# Cached: THEA 408
# Fetching: THEA 409
# Fetching: THEA 410
# Cached: THEA 411
# Fetching: THEA 412
# Fetching: THEA 413
# Fetching: THEA 414
# Fetching: THEA 415
# Fetching: THEA 416
# Fetching: THEA 417
# Fetching: THEA 418
# Cached: THEA 419
# Cached: THEA 420
# Cached: THEA 421
# Cached: THEA 422
# Fetching: THEA 423
# Fetching: THEA 424
# Cached: THEA 425
# Cached: THEA 426
# Fetching: THEA 427
# Cached: THEA 428
# Cached: THEA 429
# Fetching: THEA 430
# Cached: THEA 431
# Fetching: THEA 432
# Fetching: THEA 433
# Cached: THEA 434
# Fetching: THEA 435
# Fetching: THEA 436
# Fetching: THEA 437
# Cached: THEA 438
# Cached: THEA 441
# Fetching: THEA 442
# Fetching: THEA 443
# Fetching: THEA 444
# Fetching: THEA 445
# Cached: THEA 446
# Cached: THEA 447
# Fetching: THEA 448
# Fetching: THEA 449
# Cached: THEA 450
# Fetching: THEA 451
# Fetching: THEA 452
# Cached: THEA 453
# Cached: THEA 454
# Cached: THEA 455
# Fetching: THEA 456
# Fetching: THEA 457
# Fetching: THEA 458
# Fetching: THEA 461
# Cached: THEA 462
# Cached: THEA 466
# Fetching: THEA 467
# Fetching: THEA 468
# Cached: THEA 469
# Fetching: THEA 470
# Fetching: THEA 471
# Fetching: THEA 472
# Fetching: THEA 473
# Fetching: THEA 474
# Cached: THEA 475
# Cached: THEA 476
# Cached: THEA 477
# Cached: THEA 478
# Cached: THEA 479
# Fetching: THEA 480
# Fetching: THEA 481
# Cached: THEA 482
# Fetching: THEA 483
# Fetching: THEA 484
# Fetching: THEA 485
# Cached: THEA 486
# Cached: THEA 489
# Cached: THEA 490
# Cached: THEA 491
# Fetching: THEA 492
# Cached: THEA 493
# Fetching: THEA 494
# Cached: THEA 495
# Cached: THEA 496
# Fetching: THEA 497
# Cached: THEA 498
# Fetching: THEA 519
# Cached: THEA 522
# Cached: THEA 530
# Cached: THEA 550
# Cached: THEA 551
# Cached: THEA 557
# Cached: THEA 559
# Fetching: THEA 560
# Cached: THEA 561
# Fetching: THEA 562
# Fetching: THEA 564
# Fetching: THEA 571
# Fetching: THEA 572
# Fetching: THEA 573
# Fetching: THEA 574
# Cached: THEA 591
# Fetching: THEA 594
# Cached: THEA 595
# Fetching: THEA 596
# Cached: THEA 599
# 175: THEA
# Cached: TMGT 366
# Fetching: TMGT 367
# Fetching: TMGT 460
# Cached: TMGT 461
# 176: TMGT
# Fetching: TRST 201
# Fetching: TRST 403
# Fetching: TRST 407
# Cached: TRST 410
# Fetching: TRST 412
# Fetching: TRST 413
# Fetching: TRST 415
# Fetching: TRST 419
# Fetching: TRST 422
# Fetching: TRST 430
# Fetching: TRST 431
# Fetching: TRST 432
# Cached: TRST 500
# Fetching: TRST 501
# Cached: TRST 502
# Cached: TRST 503
# Cached: TRST 505
# Fetching: TRST 506
# Fetching: TRST 508
# Cached: TRST 540
# Fetching: TRST 541
# Cached: TRST 542
# Fetching: TRST 543
# Fetching: TRST 545
# Fetching: TRST 580
# 177: TRST
# Fetching: TURK 199
# Fetching: TURK 201
# Cached: TURK 202
# Fetching: TURK 270
# Fetching: TURK 403
# Cached: TURK 404
# Fetching: TURK 405
# Cached: TURK 406
# Cached: TURK 490
# 178: TURK
# Fetching: UKR 101
# Fetching: UKR 102
# Fetching: UKR 113
# Cached: UKR 199
# Fetching: UKR 201
# Cached: UKR 202
# Fetching: UKR 218
# Fetching: UKR 498
# 179: UKR
# Fetching: UP 101
# Fetching: UP 111
# Cached: UP 116
# Cached: UP 136
# Cached: UP 160
# Cached: UP 185
# Cached: UP 199
# Cached: UP 201
# Fetching: UP 203
# Fetching: UP 204
# Cached: UP 205
# Cached: UP 210
# Cached: UP 211
# Cached: UP 230
# Fetching: UP 260
# Fetching: UP 312
# Cached: UP 316
# Cached: UP 317
# Fetching: UP 327
# Cached: UP 330
# Fetching: UP 335
# Fetching: UP 340
# Fetching: UP 345
# Cached: UP 347
# Fetching: UP 357
# Cached: UP 390
# Cached: UP 397
# Cached: UP 401
# Fetching: UP 406
# Cached: UP 407
# Fetching: UP 409
# Cached: UP 418
# Fetching: UP 420
# Fetching: UP 423
# Fetching: UP 425
# Cached: UP 426
# Fetching: UP 427
# Fetching: UP 428
# Fetching: UP 430
# Cached: UP 431
# Fetching: UP 432
# Cached: UP 434
# Fetching: UP 436
# Cached: UP 437
# Fetching: UP 438
# Fetching: UP 441
# Fetching: UP 443
# Cached: UP 446
# Fetching: UP 447
# Fetching: UP 455
# Fetching: UP 456
# Fetching: UP 457
# Fetching: UP 460
# Fetching: UP 466
# Fetching: UP 473
# Cached: UP 475
# Cached: UP 476
# Cached: UP 478
# Fetching: UP 479
# Cached: UP 480
# Fetching: UP 481
# Fetching: UP 486
# Cached: UP 494
# Fetching: UP 501
# Fetching: UP 503
# Cached: UP 504
# Fetching: UP 505
# Cached: UP 510
# Cached: UP 511
# Fetching: UP 513
# Fetching: UP 517
# Cached: UP 519
# Fetching: UP 520
# Fetching: UP 526
# Fetching: UP 533
# Fetching: UP 545
# Fetching: UP 546
# Fetching: UP 558
# Fetching: UP 570
# Cached: UP 576
# Fetching: UP 578
# Fetching: UP 580
# Fetching: UP 587
# Fetching: UP 589
# Cached: UP 590
# Cached: UP 591
# Cached: UP 592
# Fetching: UP 594
# Cached: UP 596
# Cached: UP 597
# Cached: UP 598
# Fetching: UP 599
# 180: UP
# Fetching: VCM 290
# Cached: VCM 501
# Cached: VCM 503
# Fetching: VCM 504
# Cached: VCM 506
# Fetching: VCM 507
# Fetching: VCM 508
# Fetching: VCM 509
# Cached: VCM 513
# Cached: VCM 514
# Cached: VCM 515
# Fetching: VCM 517
# Cached: VCM 522
# Cached: VCM 524
# Fetching: VCM 527
# Fetching: VCM 528
# Cached: VCM 535
# Cached: VCM 536
# Cached: VCM 540
# Cached: VCM 542
# Fetching: VCM 547
# Fetching: VCM 553
# Fetching: VCM 560
# Fetching: VCM 561
# Fetching: VCM 562
# Fetching: VCM 564
# Fetching: VCM 565
# Fetching: VCM 566
# Fetching: VCM 568
# Fetching: VCM 569
# Fetching: VCM 570
# Fetching: VCM 572
# Cached: VCM 577
# Fetching: VCM 581
# Cached: VCM 584
# Cached: VCM 585
# Cached: VCM 590
# Fetching: VCM 591
# Cached: VCM 592
# Cached: VCM 593
# Fetching: VCM 594
# Cached: VCM 595
# Cached: VCM 598
# Fetching: VCM 599
# Cached: VCM 608
# Fetching: VCM 614
# Cached: VCM 625
# Fetching: VCM 626
# Cached: VCM 627
# Cached: VCM 628
# Fetching: VCM 630
# Fetching: VCM 635
# Fetching: VCM 636
# Fetching: VCM 637
# Fetching: VCM 640
# Cached: VCM 641
# Fetching: VCM 643
# Fetching: VCM 644
# Cached: VCM 645
# Fetching: VCM 646
# Fetching: VCM 648
# Fetching: VCM 649
# Fetching: VCM 656
# Fetching: VCM 657
# Fetching: VCM 660
# Cached: VCM 661
# Cached: VCM 663
# Cached: VCM 667
# Fetching: VCM 672
# Cached: VCM 673
# Cached: VCM 674
# Fetching: VCM 678
# Fetching: VCM 679
# Fetching: VCM 681
# Cached: VCM 682
# Fetching: VCM 685
# Fetching: VCM 686
# Fetching: VCM 687
# Cached: VCM 688
# Cached: VCM 690
# Cached: VCM 692
# Fetching: VCM 693
# Fetching: VCM 694
# Fetching: VCM 695
# Fetching: VCM 696
# Fetching: VCM 698
# 181: VCM
# Fetching: VM 290
# Fetching: VM 601
# Fetching: VM 602
# Cached: VM 603
# Cached: VM 604
# Fetching: VM 605
# Cached: VM 606
# Fetching: VM 607
# Cached: VM 608
# Fetching: VM 610
# Fetching: VM 611
# Cached: VM 612
# Fetching: VM 613
# Fetching: VM 614
# Fetching: VM 615
# Cached: VM 616
# Cached: VM 617
# Fetching: VM 620
# Fetching: VM 622
# Fetching: VM 623
# Fetching: VM 626
# Fetching: VM 627
# Fetching: VM 635
# Cached: VM 642
# Fetching: VM 643
# Cached: VM 645
# Fetching: VM 651
# Fetching: VM 652
# Fetching: VM 653
# Fetching: VM 654
# Cached: VM 655
# Cached: VM 656
# Fetching: VM 694
# 182: VM
# Cached: WGGP 581
# 183: WGGP
# Cached: WLOF 201
# Cached: WLOF 202
# Cached: WLOF 403
# Fetching: WLOF 404
# Fetching: WLOF 405
# Fetching: WLOF 406
# Fetching: WLOF 407
# 184: WLOF
# Fetching: WRIT 199
# Cached: WRIT 300
# Cached: WRIT 303

# %%
df = pd.DataFrame(rows)

# %%
df.to_csv("catalog.csv")

# %%
# Out:
# {'label': 'Intro Computing: Non-Tech',
#  'description': 'Computing as an essential tool of academic and professional activities. Functions and interrelationships of computer system components: hardware, systems and applications software, and networks. Widely used application packages such as spreadsheets and databases. Concepts and practice of programming for the solution of simple problems in different application areas. Intended for non-science and non-engineering majors. Prerequisite: MATH 112.',
#  'creditHours': '3 hours.',
#  'courseSectionInformation': 'Prerequisite: MATH 112.',
#  'sectionDegreeAttributes': 'Quantitative Reasoning I course.',
#  'classScheduleInformation': 'Students must register for one lab-discussion and one lecture section.'}

# %%
row = pd.Series()
row["Year"] = 2026

# %%
row
# Out:
# Year    2026
# dtype: int64
